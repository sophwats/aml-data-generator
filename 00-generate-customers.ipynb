# %% [markdown]
# ## Generating Customers
#
# In this notebook we will build up an event generator for making or changing personally identifiable information (PII) for bank customers.
#
# Each event will either be a `new` customer or a `change` event.
#
# When a `new` event occurs, we will generate a new customer and a set of PII for them including their:
#     - Name
#     - Date of Birth
#     - Social Security number
#     - Bank account details
#
# When a `change` event occurs, we will select an existing customer and alter one piece of their PII.

# %% [markdown]
# #### Making Repeatable Simulations
#
# We follow the methodology laid out [here](https://chapeau.freevariable.com/2020/02/repeatable-simulation-without-boilerplate.html) to ensure that any simulations can be deterministic, and thus repeatable. This is really desirable as it enables us to replay data on new models to test them.

# %%
### Setting up repeatibility
### This is copied directly from Will's notebook
### to do - ? put into a separate file?

def makeprng(func):
    import time
    def call_with_prng(*args, prng=None, seed=None, **kwargs):
        if prng is None:
            if seed is None:
                seed = int(time.time()) & ((1 << 32) - 1)
            prng = np.random.RandomState(seed)
        return func(*args, prng=prng, seed=seed, **kwargs)
    return call_with_prng

#again copied verbatim from Will's notebook. 
#the code makes it really simple to set seeds in the scipy distributions.
def makedist(dist_cls, seed=None, prng=None, **kwargs):
    d = dist_cls(**kwargs)
    d.random_state = (seed and seed) or prng.randint((1 << 32) - 1)
    return d

# %% [markdown]
# ## Simulating Names
#
# We begin by simulating user names. For this notebook we are using a set of Faroese names, which we scrape from a webpage using `BeautifulSoup`. We follow Faroese naming convention -  female surnames end in _dóttir_ whilst male surnames end in _son_.

# %%
## this should be pushed to a different file, and the data sets we generate saved

from bs4 import BeautifulSoup
import random
import numpy as np


with open("data/faroese-female.htm") as ff:
    soup = BeautifulSoup(ff)

names = soup.find_all('a')

female_names = []
for n in names:
    try:
        female_names.append(n['title'].rsplit(' ')[0])
    except Exception:
        pass
del female_names[0]

with open("data/faroese-male.htm") as fm:
    soup = BeautifulSoup(fm)
    
mnames = soup.find_all('a')
male_names = []
for n in mnames:
    try:
        male_names.append(n['title'].rsplit(' ')[0])
    except Exception:
        pass
del male_names[0]

n_male = len(male_names)
n_female = len(female_names)

# %% [markdown]
# In this next cell we set up a generator which simulates names from the set we scraped above.

# %%
## this isn't computing the generative form of hte male names. 
@makeprng
def names(males, females, dist=0.5, prng=None, seed=None):
    random.seed(seed)
    
    n_male = len(males)
    n_female = len(females)


    while True:
        rand = random.random()
        ## this is cycling about change events. 
        print(rand)
        surname = males[prng.randint(0, n_male-1)]
        if rand < dist:
            gender = 'male'
            first_name = males[prng.randint(0, n_male-1)]
            surname = surname + 'son'
        else:
            first_name = females[prng.randint(0, n_female-1)]
            surname = surname + 'dóttir'
            gender = 'female'
            
        result = " ".join([first_name,surname])
        yield result
        
name = names(males = male_names, females = female_names, dist = 0.5, seed=123) # this is a name generator

# %%
for i in range(100):
    print(next(name))
# Out:
# 0.052363598850944326
# Herbjartur Kolfinnurson
# 0.08718667752263232
# Hákun Hervarðurson
# 0.4072417636703983
# Sólmundur Benadiktson
# 0.10770023493843905
# Niklái Aleksson
# 0.9011988779516946
# Brá Bergurdóttir
# 0.0381536661023224
# Eyðbjartur Matsson
# 0.5362020400339269
# Berta Snævardóttir
# 0.33219769850967984
# Pál Birgarson
# 0.8520866189293687
# Ata Arnbjørndóttir
# 0.1596623967219699
# Eyðsvein Liasson
# 0.3372166571092755
# Hørður Bessison
# 0.3337963946289553
# Valdi Hannisson
# 0.24516335251761112
# Ingivaldur Fríðmundurson
# 0.0016705535792228554
# Eskil Oddgeirson
# 0.4362757934152184
# Tóroddur Ásbrandurson
# 0.08761349975042287
# Jóannes Tótison
# 0.5975994644879905
# Hjalma Ábramdóttir
# 0.06987696145918243
# Hákun Ápramson
# 0.3154589737358633
# Mannbjørn Nikodemusson
# 0.44832170830694373
# Djóni Kjartanson
# 0.9053986522844989
# Billa Borgardóttir
# 0.09276456137849509
# Vilbergur Herolvurson
# 0.14217506443150107
# Hemingur Edvardson
# 0.7900718443588016
# Eyðhild Villidóttir
# 0.021235974816989245
# Vilhjálmur Ottoson
# 0.9111505480903207
# Gylta Immanueldóttir
# 0.5734080856809272
# Sólfríð Napoleondóttir
# 0.2653217052615633
# Úlvur Bergurson
# 0.8378376441951344
# Kára Melkirdóttir
# 0.7687947474799836
# Jónleyg Tristandóttir
# 0.3434621581559646
# Signheðin Tobiasson
# 0.801496591292033
# Maia Broddidóttir
# 0.2068624706661114
# Immanuel Geirolvurson
# 0.6089025261905533
# Døgg Svávardóttir
# 0.5270749521614166
# Poula Edvarddóttir
# 0.8093385246438048
# Janhild Herbjarturdóttir
# 0.3152631522159881
# Sigurð Búison
# 0.3982381514678992
# Teinar Hjalmarson
# 0.7692790899139238
# Froydis Fríðrikurdóttir
# 0.512752133864065
# Brynja Hemmingurdóttir
# 0.684837218661006
# Elspa Magnidóttir
# 0.6383532643054988
# Steinvør Helgidóttir
# 0.666657631073181
# Klára Lávusdóttir
# 0.8900985705369023
# Havdis Tráindóttir
# 0.486136470143564
# Laars Sørkvison
# 0.6684702219031471
# Marý Jónasdóttir
# 0.3745216318224833
# Ørvar Arngrímurson
# 0.03184130674110186
# Gunnar Sprotison
# 0.7541731718588721
# Hjørdis Arnoddurdóttir
# 0.18146491591504088
# Ásbjørn Korneliusson
# 0.820190184433831
# Sirið Brandurdóttir
# 0.9136459118642296
# Ronja Jónsteindóttir
# 0.6580741574010793
# Ingigerð Jústinusdóttir
# 0.17012688767090822
# Fróðar Absalonson
# 0.33691615279170617
# Eyðolvur Steintórson
# 0.39119330707130273
# Geir Gabrielson
# 0.07329077812368656
# Aksel Baldurson
# 0.4567670702014537
# Elmar Jónfinnurson
# 0.5731685145105314
# Krista Brendandóttir
# 0.33610609930983404
# Tórhallur Leivurson
# 0.18906186957807647
# Yngvar Hórðurson
# 0.08815729492607605
# Vilmar Vagnurson
# 0.6283175227307927
# Billa Ottardóttir
# 0.01282910925261338
# Tormóður Elianson
# 0.35191368309820115
# Albin Jørmundurson
# 0.22912976448028421
# Hendrikur Pólson
# 0.5319974906817646
# Bera Bernharddóttir
# 0.7236633511192414
# Guðbjørg Arnardóttir
# 0.9091532756367794
# Halldóra Gustavdóttir
# 0.6388008392431014
# Hallvør Hørðurdóttir
# 0.9917930997519157
# Una Jallgrímurdóttir
# 0.9640591723038818
# Jófríð Ingimundurdóttir
# 0.6299907097242456
# Maifríð Úlvheðindóttir
# 0.2333731840861596
# Hagbarður Arnsveinson
# 0.48381148264314666
# Sveinbjørn Ørnolvurson
# 0.17758973057390504
# Torleygur Halgirson
# 0.9919577727942169
# Signuva Torridóttir
# 0.44449992014907413
# Bresti Baldvinson
# 0.7516501580275301
# Irena Ímundurdóttir
# 0.044129856006443924
# Hannus Gylvison
# 0.13472760063663358
# Kaleb Ovison
# 0.19317697004235368
# Hermóður Julianson
# 0.2563623472965425
# Jonn Ingvaldurson
# 0.3520475304496762
# Súnmundur Ørnolvurson
# 0.2719298523267516
# Jørmundur Arnórson
# 0.43426858361265375
# Adrian Ásmóðurson
# 0.42035731673505405
# Hjalmar Esbernson
# 0.10862083448160165
# Eyðolvur Ásarson
# 0.06260877482831684
# Lykkir Elmarson
# 0.3550614469278791
# Jóhannis Ásleivurson
# 0.08878890486736224
# Jøkil Róarson
# 0.4332003138771612
# Kári Oyolvurson
# 0.008561214772869308
# Sørli Borgarson
# 0.5358010186065645
# Trina Ísmaldóttir
# 0.07348399271505246
# Summarliði Frímannson
# 0.694205914699235
# Eyð Rósingurdóttir
# 0.40420726708424737
# Jónleivur Jaspurson
# 0.9853481748883274
# Magga Meinharddóttir
# 0.26254001971904994
# Aleks Korneliusson
# 0.47251074040704333
# Steinfinnur Baldvinson

# %% [markdown]
# ## Change events
#
# Before we generating more PII, we set up a simple `surname_change` function. At the moment this function simply selects a customer at random and changes their surname.

# %%
@makeprng
def surname_change(old_name, males, prng=None, seed=None):
    ## takes in old name
    ## assumes name is of the form 'first name, surname'
    surname = males[prng.randint(0, n_male-1)]
    
    ## checks to see if male or female. 
    if 'dóttir' in old_name:
        surname = surname + 'dóttir'
        
    else:
        surname = surname + 'son'
    
    new_name = " ".join([old_name.split()[0], surname])
    return new_name

# %% [markdown]
# ## Customer generator
#
# We now have enough functionality to make a basic customer generator. The generator will first create `N` new users. Once `N` users have been created each subsequent event will:
#     - generate another new user with probability `p`
#     - change the surname of an existing user with probability `1-p`
#
# Events take the form `(timestamp, (event_type, (new_name, old_name)))` where
#     - `timestamp` is an arbitary time of the generation or change
#     - `event_type` is either `change` or `new`
#     - `new_name` and `old_name` will be the same for `new` events, and will vary if the name has changed.

# %%
from itertools import count
from scipy import stats
numb_users = count()

@makeprng
def name_stream(mu, names_str, N=10, p=0.85, prng=None, seed=None):
    nusers = 0
    dic_names = {}
    poiss = makedist(stats.poisson, prng=prng, mu = mu)
    prng = np.random.RandomState(seed or 0xda7aba5e)

    while True:
        if nusers < N: 
            nusers = next(numb_users)
            offset = poiss.rvs()
            name = next(names_str)
            y = ('new', name, name)
            dic_names[nusers]= name

        else:
            offset = poiss.rvs()
            rand = prng.random_sample()
            ## this is cycling after change events. 
            print(rand)
            if rand < p:
                nusers = next(numb_users)
                name = next(names_str)
                y = ('new', name, name)
                dic_names[nusers]= name
            else:
                to_edit = prng.randint(0, nusers)
                print("to edit", to_edit, sep = " ")
                new_name = surname_change(old_name = dic_names[to_edit], males = male_names, prng=prng)
                y = ('change', (new_name, dic_names[to_edit]))
                dic_names[to_edit] = new_name
                
        
        yield (offset, y)

# %%
name = names(males = male_names, females = female_names, dist = 0.5, seed=123) # this is a name generator
sim= name_stream(mu=3, names_str = name, N=10, p=0.85, seed=143)

# %%
for i in range(200):
    print(next(sim))
# Out:
# 0.052363598850944326
# {0: 'Herbjartur Kolfinnurson'}
# (3, ('new', 'Herbjartur Kolfinnurson', 'Herbjartur Kolfinnurson'))
# 0.08718667752263232
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson'}
# (5, ('new', 'Hákun Hervarðurson', 'Hákun Hervarðurson'))
# 0.4072417636703983
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson'}
# (4, ('new', 'Sólmundur Benadiktson', 'Sólmundur Benadiktson'))
# 0.10770023493843905
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson'}
# (2, ('new', 'Niklái Aleksson', 'Niklái Aleksson'))
# 0.9011988779516946
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir'}
# (4, ('new', 'Brá Bergurdóttir', 'Brá Bergurdóttir'))
# 0.0381536661023224
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson'}
# (3, ('new', 'Eyðbjartur Matsson', 'Eyðbjartur Matsson'))
# 0.5362020400339269
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir'}
# (0, ('new', 'Berta Snævardóttir', 'Berta Snævardóttir'))
# 0.33219769850967984
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson'}
# (3, ('new', 'Pál Birgarson', 'Pál Birgarson'))
# 0.8520866189293687
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir'}
# (4, ('new', 'Ata Arnbjørndóttir', 'Ata Arnbjørndóttir'))
# 0.1596623967219699
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson'}
# (3, ('new', 'Eyðsvein Liasson', 'Eyðsvein Liasson'))
# 0.3372166571092755
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Bessison'}
# (3, ('new', 'Hørður Bessison', 'Hørður Bessison'))
# 0.7377549616506409
# 0.3337963946289553
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Bessison', 11: 'Valdi Hannisson'}
# (3, ('new', 'Valdi Hannisson', 'Valdi Hannisson'))
# 0.3399547406731225
# 0.24516335251761112
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Bessison', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson'}
# (3, ('new', 'Ingivaldur Fríðmundurson', 'Ingivaldur Fríðmundurson'))
# 0.46809010087334957
# 0.0016705535792228554
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Bessison', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Oddgeirson'}
# (3, ('new', 'Eskil Oddgeirson', 'Eskil Oddgeirson'))
# 0.42393801564202327
# 0.4362757934152184
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Bessison', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Oddgeirson', 14: 'Tóroddur Ásbrandurson'}
# (2, ('new', 'Tóroddur Ásbrandurson', 'Tóroddur Ásbrandurson'))
# 0.5683196137805934
# 0.08761349975042287
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Bessison', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Oddgeirson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Tótison'}
# (2, ('new', 'Jóannes Tótison', 'Jóannes Tótison'))
# 0.8812808581628789
# to edit 13
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Bessison', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Oddbjørnson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Tótison'}
# (0, ('change', ('Eskil Oddbjørnson', 'Eskil Oddgeirson')))
# 0.008783956523436887
# 0.5975994644879905
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Bessison', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Oddbjørnson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Tótison', 16: 'Hjalma Ábramdóttir'}
# (1, ('new', 'Hjalma Ábramdóttir', 'Hjalma Ábramdóttir'))
# 0.19923775690534407
# 0.06987696145918243
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Bessison', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Oddbjørnson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Tótison', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson'}
# (6, ('new', 'Hákun Ápramson', 'Hákun Ápramson'))
# 0.16726878825655045
# 0.3154589737358633
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Bessison', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Oddbjørnson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Tótison', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson'}
# (1, ('new', 'Mannbjørn Nikodemusson', 'Mannbjørn Nikodemusson'))
# 0.9689909052664663
# to edit 10
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Oddbjørnson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Tótison', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson'}
# (2, ('change', ('Hørður Ernstson', 'Hørður Bessison')))
# 0.14668958097428708
# 0.44832170830694373
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Oddbjørnson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Tótison', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson'}
# (1, ('new', 'Djóni Kjartanson', 'Djóni Kjartanson'))
# 0.9724372968770228
# to edit 15
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Oddbjørnson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson'}
# (0, ('change', ('Jóannes Eskilson', 'Jóannes Tótison')))
# 0.9766817174300038
# to edit 13
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson'}
# (1, ('change', ('Eskil Robertson', 'Eskil Oddbjørnson')))
# 0.5639350346366817
# 0.9053986522844989
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir'}
# (4, ('new', 'Billa Borgardóttir', 'Billa Borgardóttir'))
# 0.2715429307545252
# 0.09276456137849509
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Herolvurson'}
# (4, ('new', 'Vilbergur Herolvurson', 'Vilbergur Herolvurson'))
# 0.5073766636637834
# 0.14217506443150107
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Herolvurson', 22: 'Hemingur Edvardson'}
# (2, ('new', 'Hemingur Edvardson', 'Hemingur Edvardson'))
# 0.5992975843665959
# 0.7900718443588016
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Herolvurson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir'}
# (4, ('new', 'Eyðhild Villidóttir', 'Eyðhild Villidóttir'))
# 0.9867121921457211
# to edit 21
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Matsson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir'}
# (5, ('change', ('Vilbergur Bastianson', 'Vilbergur Herolvurson')))
# 0.954447142496547
# to edit 5
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir'}
# (2, ('change', ('Eyðbjartur Sunnleivurson', 'Eyðbjartur Matsson')))
# 0.18289426904231965
# 0.021235974816989245
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson'}
# (7, ('new', 'Vilhjálmur Ottoson', 'Vilhjálmur Ottoson'))
# 0.8159387620282018
# 0.9111505480903207
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir'}
# (6, ('new', 'Gylta Immanueldóttir', 'Gylta Immanueldóttir'))
# 0.28461482994857734
# 0.5734080856809272
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir'}
# (3, ('new', 'Sólfríð Napoleondóttir', 'Sólfríð Napoleondóttir'))
# 0.6674764305495762
# 0.2653217052615633
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Aleksson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson'}
# (3, ('new', 'Úlvur Bergurson', 'Úlvur Bergurson'))
# 0.9841564861592056
# to edit 3
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Borgarson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson'}
# (2, ('change', ('Niklái Borgarson', 'Niklái Aleksson')))
# 0.805128611851796
# 0.8378376441951344
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Borgarson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Melkirdóttir'}
# (6, ('new', 'Kára Melkirdóttir', 'Kára Melkirdóttir'))
# 0.8241092326570796
# 0.7687947474799836
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Borgarson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Melkirdóttir', 29: 'Jónleyg Tristandóttir'}
# (3, ('new', 'Jónleyg Tristandóttir', 'Jónleyg Tristandóttir'))
# 0.12117513632295385
# 0.3434621581559646
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Borgarson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Melkirdóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson'}
# (9, ('new', 'Signheðin Tobiasson', 'Signheðin Tobiasson'))
# 0.9366164148154632
# to edit 28
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Borgarson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson'}
# (2, ('change', ('Kára Húnidóttir', 'Kára Melkirdóttir')))
# 0.4503177309961064
# 0.801496591292033
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Borgarson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir'}
# (2, ('new', 'Maia Broddidóttir', 'Maia Broddidóttir'))
# 0.26099843655782673
# 0.2068624706661114
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Borgarson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson'}
# (3, ('new', 'Immanuel Geirolvurson', 'Immanuel Geirolvurson'))
# 0.044117803111854315
# 0.6089025261905533
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Borgarson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir'}
# (7, ('new', 'Døgg Svávardóttir', 'Døgg Svávardóttir'))
# 0.2675560846879462
# 0.5270749521614166
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Borgarson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir'}
# (6, ('new', 'Poula Edvarddóttir', 'Poula Edvarddóttir'))
# 0.6677133276126745
# 0.8093385246438048
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Borgarson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir'}
# (0, ('new', 'Janhild Herbjarturdóttir', 'Janhild Herbjarturdóttir'))
# 0.3501571987083081
# 0.3152631522159881
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Borgarson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison'}
# (2, ('new', 'Sigurð Búison', 'Sigurð Búison'))
# 0.054122381232393324
# 0.3982381514678992
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Borgarson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson'}
# (2, ('new', 'Teinar Hjalmarson', 'Teinar Hjalmarson'))
# 0.8739766010928417
# to edit 3
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson'}
# (2, ('change', ('Niklái Eliasson', 'Niklái Borgarson')))
# 0.45474882729638477
# 0.7692790899139238
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir'}
# (5, ('new', 'Froydis Fríðrikurdóttir', 'Froydis Fríðrikurdóttir'))
# 0.0130135309715248
# 0.512752133864065
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir'}
# (5, ('new', 'Brynja Hemmingurdóttir', 'Brynja Hemmingurdóttir'))
# 0.6753476062370662
# 0.684837218661006
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir', 40: 'Elspa Magnidóttir'}
# (4, ('new', 'Elspa Magnidóttir', 'Elspa Magnidóttir'))
# 0.5240385703474991
# 0.6383532643054988
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir', 40: 'Elspa Magnidóttir', 41: 'Steinvør Helgidóttir'}
# (2, ('new', 'Steinvør Helgidóttir', 'Steinvør Helgidóttir'))
# 0.36202498232639546
# 0.666657631073181
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir', 40: 'Elspa Magnidóttir', 41: 'Steinvør Helgidóttir', 42: 'Klára Lávusdóttir'}
# (5, ('new', 'Klára Lávusdóttir', 'Klára Lávusdóttir'))
# 0.43286200055383095
# 0.8900985705369023
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir', 40: 'Elspa Magnidóttir', 41: 'Steinvør Helgidóttir', 42: 'Klára Lávusdóttir', 43: 'Havdis Tráindóttir'}
# (2, ('new', 'Havdis Tráindóttir', 'Havdis Tráindóttir'))
# 0.8278848377576689
# 0.486136470143564
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir', 40: 'Elspa Magnidóttir', 41: 'Steinvør Helgidóttir', 42: 'Klára Lávusdóttir', 43: 'Havdis Tráindóttir', 44: 'Laars Sørkvison'}
# (3, ('new', 'Laars Sørkvison', 'Laars Sørkvison'))
# 0.7496779405358596
# 0.6684702219031471
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir', 40: 'Elspa Magnidóttir', 41: 'Steinvør Helgidóttir', 42: 'Klára Lávusdóttir', 43: 'Havdis Tráindóttir', 44: 'Laars Sørkvison', 45: 'Marý Jónasdóttir'}
# (2, ('new', 'Marý Jónasdóttir', 'Marý Jónasdóttir'))
# 0.8018649752638543
# 0.3745216318224833
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir', 40: 'Elspa Magnidóttir', 41: 'Steinvør Helgidóttir', 42: 'Klára Lávusdóttir', 43: 'Havdis Tráindóttir', 44: 'Laars Sørkvison', 45: 'Marý Jónasdóttir', 46: 'Ørvar Arngrímurson'}
# (4, ('new', 'Ørvar Arngrímurson', 'Ørvar Arngrímurson'))
# 0.034647160392927034
# 0.03184130674110186
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir', 40: 'Elspa Magnidóttir', 41: 'Steinvør Helgidóttir', 42: 'Klára Lávusdóttir', 43: 'Havdis Tráindóttir', 44: 'Laars Sørkvison', 45: 'Marý Jónasdóttir', 46: 'Ørvar Arngrímurson', 47: 'Gunnar Sprotison'}
# (5, ('new', 'Gunnar Sprotison', 'Gunnar Sprotison'))
# 0.5914122350666787
# 0.7541731718588721
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir', 40: 'Elspa Magnidóttir', 41: 'Steinvør Helgidóttir', 42: 'Klára Lávusdóttir', 43: 'Havdis Tráindóttir', 44: 'Laars Sørkvison', 45: 'Marý Jónasdóttir', 46: 'Ørvar Arngrímurson', 47: 'Gunnar Sprotison', 48: 'Hjørdis Arnoddurdóttir'}
# (4, ('new', 'Hjørdis Arnoddurdóttir', 'Hjørdis Arnoddurdóttir'))
# 0.7688319457443592
# 0.18146491591504088
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir', 40: 'Elspa Magnidóttir', 41: 'Steinvør Helgidóttir', 42: 'Klára Lávusdóttir', 43: 'Havdis Tráindóttir', 44: 'Laars Sørkvison', 45: 'Marý Jónasdóttir', 46: 'Ørvar Arngrímurson', 47: 'Gunnar Sprotison', 48: 'Hjørdis Arnoddurdóttir', 49: 'Ásbjørn Korneliusson'}
# (2, ('new', 'Ásbjørn Korneliusson', 'Ásbjørn Korneliusson'))
# 0.8124402509946912
# 0.820190184433831
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Ernstson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir', 40: 'Elspa Magnidóttir', 41: 'Steinvør Helgidóttir', 42: 'Klára Lávusdóttir', 43: 'Havdis Tráindóttir', 44: 'Laars Sørkvison', 45: 'Marý Jónasdóttir', 46: 'Ørvar Arngrímurson', 47: 'Gunnar Sprotison', 48: 'Hjørdis Arnoddurdóttir', 49: 'Ásbjørn Korneliusson', 50: 'Sirið Brandurdóttir'}
# (1, ('new', 'Sirið Brandurdóttir', 'Sirið Brandurdóttir'))
# 0.8852049285925631
# to edit 10
# {0: 'Herbjartur Kolfinnurson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Vilbergurson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Fríðmundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Bastianson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Svávardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir', 40: 'Elspa Magnidóttir', 41: 'Steinvør Helgidóttir', 42: 'Klára Lávusdóttir', 43: 'Havdis Tráindóttir', 44: 'Laars Sørkvison', 45: 'Marý Jónasdóttir', 46: 'Ørvar Arngrímurson', 47: 'Gunnar Sprotison', 48: 'Hjørdis Arnoddurdóttir', 49: 'Ásbjørn Korneliusson', 50: 'Sirið Brandurdóttir'}
# (1, ('change', ('Hørður Vilbergurson', 'Hørður Ernstson')))
# 0.044776599257186134
# 0.9136459118642296
# ...
# (4, ('new', 'Belinda Kaidóttir', 'Belinda Kaidóttir'))
# 0.6597473451497272
# 0.256851738048816
# {0: 'Herbjartur Ragnarson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Vilbergurson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Hermundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Gripurson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Beinardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir', 40: 'Elspa Magnidóttir', 41: 'Steinvør Helgidóttir', 42: 'Klára Lávusdóttir', 43: 'Havdis Tráindóttir', 44: 'Laars Símeonson', 45: 'Marý Jónasdóttir', 46: 'Ørvar Arngrímurson', 47: 'Gunnar Sprotison', 48: 'Hjørdis Arnoddurdóttir', 49: 'Ásbjørn Korneliusson', 50: 'Sirið Loðindóttir', 51: 'Ronja Jónsteindóttir', 52: 'Ingigerð Jústinusdóttir', 53: 'Fróðar Absalonson', 54: 'Eyðolvur Flosison', 55: 'Geir Gabrielson', 56: 'Aksel Baldurson', 57: 'Elmar Jónfinnurson', 58: 'Krista Egildóttir', 59: 'Tórhallur Hallgrímurson', 60: 'Yngvar Hórðurson', 61: 'Vilmar Vagnurson', 62: 'Billa Ottardóttir', 63: 'Tormóður Elianson', 64: 'Albin Jørmundurson', 65: 'Hendrikur Pólson', 66: 'Bera Bernharddóttir', 67: 'Guðbjørg Arnardóttir', 68: 'Halldóra Onundurdóttir', 69: 'Hallvør Hørðurdóttir', 70: 'Una Jallgrímurdóttir', 71: 'Jófríð Ingimundurdóttir', 72: 'Maifríð Úlvheðindóttir', 73: 'Hagbarður Arnsveinson', 74: 'Sveinbjørn Ørnolvurson', 75: 'Torleygur Halgirson', 76: 'Signuva Torridóttir', 77: 'Bresti Baldvinson', 78: 'Irena Ímundurdóttir', 79: 'Hannus Gylvison', 80: 'Kaleb Ovison', 81: 'Hermóður Julianson', 82: 'Jonn Ingvaldurson', 83: 'Súnmundur Ørnolvurson', 84: 'Jørmundur Arnórson', 85: 'Adrian Ásmóðurson', 86: 'Hjalmar Esbernson', 87: 'Eyðolvur Ásarson', 88: 'Lykkir Fálgeirson', 89: 'Jóhannis Ásleivurson', 90: 'Jøkil Róarson', 91: 'Kári Gylvison', 92: 'Sørli Borgarson', 93: 'Trina Ísmaldóttir', 94: 'Summarliði Frímannson', 95: 'Eyð Rósingurdóttir', 96: 'Jónleivur Jaspurson', 97: 'Magga Meinharddóttir', 98: 'Aleks Korneliusson', 99: 'Steinfinnur Baldvinson', 100: 'Erika Eyðbjørndóttir', 101: 'Marius Oddleivurson', 102: 'Bjørn Helgison', 103: 'Oddný Reimardóttir', 104: 'Luna Laarsdóttir', 105: 'Marin Havsteindóttir', 106: 'Meinar Áskilson', 107: 'Sigurbjørg Sigbjarturdóttir', 108: 'Bergný Høskuldurdóttir', 109: 'Maks Jóhannesson', 110: 'Játmundur Oymundurson', 111: 'Høgnar Eindrison', 112: 'Vónbjørt Gíslidóttir', 113: 'Onundur Jatmundurson', 114: 'Gloria Knúturdóttir', 115: 'Svanna Oddmundurdóttir', 116: 'Kálvur Hansson', 117: 'Heiðveig Jákupdóttir', 118: 'Roda Vigfúsdóttir', 119: 'Bjølla Hallbjørndóttir', 120: 'Mattias Gunnsteinson', 121: 'Elias Rafaelson', 122: 'Ásthild Rógvidóttir', 123: 'Jónhild Oysteindóttir', 124: 'Gerda Esekieldóttir', 125: 'Hera Leodóttir', 126: 'Sólbjørn Aggusteinusson', 127: 'Syftun Syftunson', 128: 'Skofti Tókison', 129: 'Gylta Sámaldóttir', 130: 'Gunnálvur Gudfinnurson', 131: 'Snjófríð Vigfúsdóttir', 132: 'Elspa Hórðurdóttir', 133: 'Hallvør Hjálmardóttir', 134: 'Dagmar Aggusteinusdóttir', 135: 'Gísli Stígurson', 136: 'Píl Heinidóttir', 137: 'Hagbarður Antinesson', 138: 'Lea Kristindóttir', 139: 'Finngerð Vilmardóttir', 140: 'Felisia Rómundurdóttir', 141: 'Bragi Ingmarson', 142: 'Malan Dáviddóttir', 143: 'Marja Hallbergurdóttir', 144: 'Sonni Eyðbjørnson', 145: 'Rebekka Húnbogidóttir', 146: 'Arinbjørn Tórolvurson', 147: 'Hannis Nóison', 148: 'Jóanna Hámundurdóttir', 149: 'Máur Bernarson', 150: ...
# (1, ('new', 'Mortan Havsteinson', 'Mortan Havsteinson'))
# 0.9334844100803364
# to edit 77
# {0: 'Herbjartur Ragnarson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Vilbergurson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Hermundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Gripurson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Beinardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir', 40: 'Elspa Magnidóttir', 41: 'Steinvør Helgidóttir', 42: 'Klára Lávusdóttir', 43: 'Havdis Tráindóttir', 44: 'Laars Símeonson', 45: 'Marý Jónasdóttir', 46: 'Ørvar Arngrímurson', 47: 'Gunnar Sprotison', 48: 'Hjørdis Arnoddurdóttir', 49: 'Ásbjørn Korneliusson', 50: 'Sirið Loðindóttir', 51: 'Ronja Jónsteindóttir', 52: 'Ingigerð Jústinusdóttir', 53: 'Fróðar Absalonson', 54: 'Eyðolvur Flosison', 55: 'Geir Gabrielson', 56: 'Aksel Baldurson', 57: 'Elmar Jónfinnurson', 58: 'Krista Egildóttir', 59: 'Tórhallur Hallgrímurson', 60: 'Yngvar Hórðurson', 61: 'Vilmar Vagnurson', 62: 'Billa Ottardóttir', 63: 'Tormóður Elianson', 64: 'Albin Jørmundurson', 65: 'Hendrikur Pólson', 66: 'Bera Bernharddóttir', 67: 'Guðbjørg Arnardóttir', 68: 'Halldóra Onundurdóttir', 69: 'Hallvør Hørðurdóttir', 70: 'Una Jallgrímurdóttir', 71: 'Jófríð Ingimundurdóttir', 72: 'Maifríð Úlvheðindóttir', 73: 'Hagbarður Arnsveinson', 74: 'Sveinbjørn Ørnolvurson', 75: 'Torleygur Halgirson', 76: 'Signuva Torridóttir', 77: 'Bresti Eldbjørnson', 78: 'Irena Ímundurdóttir', 79: 'Hannus Gylvison', 80: 'Kaleb Ovison', 81: 'Hermóður Julianson', 82: 'Jonn Ingvaldurson', 83: 'Súnmundur Ørnolvurson', 84: 'Jørmundur Arnórson', 85: 'Adrian Ásmóðurson', 86: 'Hjalmar Esbernson', 87: 'Eyðolvur Ásarson', 88: 'Lykkir Fálgeirson', 89: 'Jóhannis Ásleivurson', 90: 'Jøkil Róarson', 91: 'Kári Gylvison', 92: 'Sørli Borgarson', 93: 'Trina Ísmaldóttir', 94: 'Summarliði Frímannson', 95: 'Eyð Rósingurdóttir', 96: 'Jónleivur Jaspurson', 97: 'Magga Meinharddóttir', 98: 'Aleks Korneliusson', 99: 'Steinfinnur Baldvinson', 100: 'Erika Eyðbjørndóttir', 101: 'Marius Oddleivurson', 102: 'Bjørn Helgison', 103: 'Oddný Reimardóttir', 104: 'Luna Laarsdóttir', 105: 'Marin Havsteindóttir', 106: 'Meinar Áskilson', 107: 'Sigurbjørg Sigbjarturdóttir', 108: 'Bergný Høskuldurdóttir', 109: 'Maks Jóhannesson', 110: 'Játmundur Oymundurson', 111: 'Høgnar Eindrison', 112: 'Vónbjørt Gíslidóttir', 113: 'Onundur Jatmundurson', 114: 'Gloria Knúturdóttir', 115: 'Svanna Oddmundurdóttir', 116: 'Kálvur Hansson', 117: 'Heiðveig Jákupdóttir', 118: 'Roda Vigfúsdóttir', 119: 'Bjølla Hallbjørndóttir', 120: 'Mattias Gunnsteinson', 121: 'Elias Rafaelson', 122: 'Ásthild Rógvidóttir', 123: 'Jónhild Oysteindóttir', 124: 'Gerda Esekieldóttir', 125: 'Hera Leodóttir', 126: 'Sólbjørn Aggusteinusson', 127: 'Syftun Syftunson', 128: 'Skofti Tókison', 129: 'Gylta Sámaldóttir', 130: 'Gunnálvur Gudfinnurson', 131: 'Snjófríð Vigfúsdóttir', 132: 'Elspa Hórðurdóttir', 133: 'Hallvør Hjálmardóttir', 134: 'Dagmar Aggusteinusdóttir', 135: 'Gísli Stígurson', 136: 'Píl Heinidóttir', 137: 'Hagbarður Antinesson', 138: 'Lea Kristindóttir', 139: 'Finngerð Vilmardóttir', 140: 'Felisia Rómundurdóttir', 141: 'Bragi Ingmarson', 142: 'Malan Dáviddóttir', 143: 'Marja Hallbergurdóttir', 144: 'Sonni Eyðbjørnson', 145: 'Rebekka Húnbogidóttir', 146: 'Arinbjørn Tórolvurson', 147: 'Hannis Nóison', 148: 'Jóanna Hámundurdóttir', 149: 'Máur Bernarson', 150 ...
# (2, ('change', ('Bresti Eldbjørnson', 'Bresti Baldvinson')))
# 0.8344916757537035
# 0.8327770443873531
# {0: 'Herbjartur Ragnarson', 1: 'Hákun Hervarðurson', 2: 'Sólmundur Benadiktson', 3: 'Niklái Eliasson', 4: 'Brá Bergurdóttir', 5: 'Eyðbjartur Sunnleivurson', 6: 'Berta Snævardóttir', 7: 'Pál Birgarson', 8: 'Ata Arnbjørndóttir', 9: 'Eyðsvein Liasson', 10: 'Hørður Vilbergurson', 11: 'Valdi Hannisson', 12: 'Ingivaldur Hermundurson', 13: 'Eskil Robertson', 14: 'Tóroddur Ásbrandurson', 15: 'Jóannes Eskilson', 16: 'Hjalma Ábramdóttir', 17: 'Hákun Ápramson', 18: 'Mannbjørn Nikodemusson', 19: 'Djóni Kjartanson', 20: 'Billa Borgardóttir', 21: 'Vilbergur Gripurson', 22: 'Hemingur Edvardson', 23: 'Eyðhild Villidóttir', 24: 'Vilhjálmur Ottoson', 25: 'Gylta Immanueldóttir', 26: 'Sólfríð Napoleondóttir', 27: 'Úlvur Bergurson', 28: 'Kára Húnidóttir', 29: 'Jónleyg Tristandóttir', 30: 'Signheðin Tobiasson', 31: 'Maia Broddidóttir', 32: 'Immanuel Geirolvurson', 33: 'Døgg Beinardóttir', 34: 'Poula Edvarddóttir', 35: 'Janhild Herbjarturdóttir', 36: 'Sigurð Búison', 37: 'Teinar Hjalmarson', 38: 'Froydis Fríðrikurdóttir', 39: 'Brynja Hemmingurdóttir', 40: 'Elspa Magnidóttir', 41: 'Steinvør Helgidóttir', 42: 'Klára Lávusdóttir', 43: 'Havdis Tráindóttir', 44: 'Laars Símeonson', 45: 'Marý Jónasdóttir', 46: 'Ørvar Arngrímurson', 47: 'Gunnar Sprotison', 48: 'Hjørdis Arnoddurdóttir', 49: 'Ásbjørn Korneliusson', 50: 'Sirið Loðindóttir', 51: 'Ronja Jónsteindóttir', 52: 'Ingigerð Jústinusdóttir', 53: 'Fróðar Absalonson', 54: 'Eyðolvur Flosison', 55: 'Geir Gabrielson', 56: 'Aksel Baldurson', 57: 'Elmar Jónfinnurson', 58: 'Krista Egildóttir', 59: 'Tórhallur Hallgrímurson', 60: 'Yngvar Hórðurson', 61: 'Vilmar Vagnurson', 62: 'Billa Ottardóttir', 63: 'Tormóður Elianson', 64: 'Albin Jørmundurson', 65: 'Hendrikur Pólson', 66: 'Bera Bernharddóttir', 67: 'Guðbjørg Arnardóttir', 68: 'Halldóra Onundurdóttir', 69: 'Hallvør Hørðurdóttir', 70: 'Una Jallgrímurdóttir', 71: 'Jófríð Ingimundurdóttir', 72: 'Maifríð Úlvheðindóttir', 73: 'Hagbarður Arnsveinson', 74: 'Sveinbjørn Ørnolvurson', 75: 'Torleygur Halgirson', 76: 'Signuva Torridóttir', 77: 'Bresti Eldbjørnson', 78: 'Irena Ímundurdóttir', 79: 'Hannus Gylvison', 80: 'Kaleb Ovison', 81: 'Hermóður Julianson', 82: 'Jonn Ingvaldurson', 83: 'Súnmundur Ørnolvurson', 84: 'Jørmundur Arnórson', 85: 'Adrian Ásmóðurson', 86: 'Hjalmar Esbernson', 87: 'Eyðolvur Ásarson', 88: 'Lykkir Fálgeirson', 89: 'Jóhannis Ásleivurson', 90: 'Jøkil Róarson', 91: 'Kári Gylvison', 92: 'Sørli Borgarson', 93: 'Trina Ísmaldóttir', 94: 'Summarliði Frímannson', 95: 'Eyð Rósingurdóttir', 96: 'Jónleivur Jaspurson', 97: 'Magga Meinharddóttir', 98: 'Aleks Korneliusson', 99: 'Steinfinnur Baldvinson', 100: 'Erika Eyðbjørndóttir', 101: 'Marius Oddleivurson', 102: 'Bjørn Helgison', 103: 'Oddný Reimardóttir', 104: 'Luna Laarsdóttir', 105: 'Marin Havsteindóttir', 106: 'Meinar Áskilson', 107: 'Sigurbjørg Sigbjarturdóttir', 108: 'Bergný Høskuldurdóttir', 109: 'Maks Jóhannesson', 110: 'Játmundur Oymundurson', 111: 'Høgnar Eindrison', 112: 'Vónbjørt Gíslidóttir', 113: 'Onundur Jatmundurson', 114: 'Gloria Knúturdóttir', 115: 'Svanna Oddmundurdóttir', 116: 'Kálvur Hansson', 117: 'Heiðveig Jákupdóttir', 118: 'Roda Vigfúsdóttir', 119: 'Bjølla Hallbjørndóttir', 120: 'Mattias Gunnsteinson', 121: 'Elias Rafaelson', 122: 'Ásthild Rógvidóttir', 123: 'Jónhild Oysteindóttir', 124: 'Gerda Esekieldóttir', 125: 'Hera Leodóttir', 126: 'Sólbjørn Aggusteinusson', 127: 'Syftun Syftunson', 128: 'Skofti Tókison', 129: 'Gylta Sámaldóttir', 130: 'Gunnálvur Gudfinnurson', 131: 'Snjófríð Vigfúsdóttir', 132: 'Elspa Hórðurdóttir', 133: 'Hallvør Hjálmardóttir', 134: 'Dagmar Aggusteinusdóttir', 135: 'Gísli Stígurson', 136: 'Píl Heinidóttir', 137: 'Hagbarður Antinesson', 138: 'Lea Kristindóttir', 139: 'Finngerð Vilmardóttir', 140: 'Felisia Rómundurdóttir', 141: 'Bragi Ingmarson', 142: 'Malan Dáviddóttir', 143: 'Marja Hallbergurdóttir', 144: 'Sonni Eyðbjørnson', 145: 'Rebekka Húnbogidóttir', 146: 'Arinbjørn Tórolvurson', 147: 'Hannis Nóison', 148: 'Jóanna Hámundurdóttir', 149: 'Máur Bernarson', 150 ...
# (3, ('new', 'Marianna Ápramdóttir', 'Marianna Ápramdóttir'))
