# %% [markdown]
# ## Generating Customers
#
# In this notebook we will build up an event generator for making or changing personally identifiable information (PII) for bank customers.
#
# Each event will either be a `new` customer or a `change` event.
#
# When a `new` event occurs, we will generate a new customer and a set of PII for them including their:
#     - Name
#     - Date of Birth
#     - Social Security number
#     - Bank account details
#
# When a `change` event occurs, we will select an existing customer and alter one piece of their PII.

# %% [markdown]
# #### Making Repeatable Simulations
#
# We follow the methodology laid out [here](https://chapeau.freevariable.com/2020/02/repeatable-simulation-without-boilerplate.html) to ensure that any simulations can be deterministic, and thus repeatable. This is really desirable as it enables us to replay data on new models to test them.

# %%
### Setting up repeatibility
### This is copied directly from Will's notebook
### to do - ? put into a separate file?

def makeprng(func):
    import time
    def call_with_prng(*args, prng=None, seed=None, **kwargs):
        if prng is None:
            if seed is None:
                seed = int(time.time()) & ((1 << 32) - 1)
            prng = np.random.RandomState(seed)
        return func(*args, prng=prng, seed=seed, **kwargs)
    return call_with_prng

#again copied verbatim from Will's notebook. 
#the code makes it really simple to set seeds in the scipy distributions.
def makedist(dist_cls, seed=None, prng=None, **kwargs):
    d = dist_cls(**kwargs)
    d.random_state = (seed and seed) or prng.randint((1 << 32) - 1)
    return d

# %% [markdown]
# ## Simulating Names
#
# We begin by simulating user names. For this notebook we are using a set of Faroese names, which we scrape from a webpage using `BeautifulSoup`. We follow Faroese naming convention -  female surnames end in _dóttir_ whilst male surnames end in _son_.

# %%
## this should be pushed to a different file, and the data sets we generate saved

from bs4 import BeautifulSoup
import random
import numpy as np


with open("data/faroese-female.htm") as ff:
    soup = BeautifulSoup(ff)

names = soup.find_all('a')

female_names = []
for n in names:
    try:
        female_names.append(n['title'].rsplit(' ')[0])
    except Exception:
        pass
del female_names[0]

with open("data/faroese-male.htm") as fm:
    soup = BeautifulSoup(fm)
    
mnames = soup.find_all('a')
male_names = []
for n in mnames:
    try:
        male_names.append(n['title'].rsplit(' ')[0])
    except Exception:
        pass
del male_names[0]

n_male = len(male_names)
n_female = len(female_names)

# %% [markdown]
# In this next cell we set up a generator which simulates names from the set we scraped above.

# %%
## this isn't computing the generative form of hte male names. 
@makeprng
def names(males, females, dist=0.5, prng=None, seed=None):
    random.seed(seed)
    
    n_male = len(males)
    n_female = len(females)


    while True:
        rand = random.random()
        ## this is cycling about change events. 
        print(rand)
        surname = males[prng.randint(0, n_male-1)]
        if rand < dist:
            gender = 'male'
            first_name = males[prng.randint(0, n_male-1)]
            surname = surname + 'son'
        else:
            first_name = females[prng.randint(0, n_female-1)]
            surname = surname + 'dóttir'
            gender = 'female'
            
        result = {'name':" ".join([first_name,surname]) }
        yield tuple(r for r in result.values())
        
name = names(males = male_names, females = female_names, dist = 0.5, seed=123) # this is a name generator

# %%
for i in range(10):
    print(next(name))
# Out:
# 0.052363598850944326
# ('Herbjartur Kolfinnurson',)
# 0.08718667752263232
# ('Hákun Hervarðurson',)
# 0.4072417636703983
# ('Sólmundur Benadiktson',)
# 0.10770023493843905
# ('Niklái Aleksson',)
# 0.9011988779516946
# ('Brá Bergurdóttir',)
# 0.0381536661023224
# ('Eyðbjartur Matsson',)
# 0.5362020400339269
# ('Berta Snævardóttir',)
# 0.33219769850967984
# ('Pál Birgarson',)
# 0.8520866189293687
# ('Ata Arnbjørndóttir',)
# 0.1596623967219699
# ('Eyðsvein Liasson',)

# %% [markdown]
# ## Change events
#
# Before we generating more PII, we set up a simple `surname_change` function. At the moment this function simply selects a customer at random and changes their surname.

# %%
@makeprng
def surname_change(old_name, males, prng=None, seed=None):
    ## takes in old name
    ## assumes name is of the form 'first name, surname'
    random.seed(seed)
    rand = random.random()
    surname = males[prng.randint(0, n_male-1)]
    
    ## checks to see if male or female. 
    if 'dóttir' in old_name:
        surname = surname + 'dóttir'
        
    else:
        surname = surname + 'son'
    
    new_name = " ".join([old_name.split()[0], surname])
    return new_name

# %% [markdown]
# ## Customer generator
#
# We now have enough functionality to make a basic customer generator. The generator will first create `N` new users. Once `N` users have been created each subsequent event will:
#     - generate another new user with probability `p`
#     - change the surname of an existing user with probability `1-p`
#
# Events take the form `(timestamp, (event_type, (new_name, old_name)))` where
#     - `timestamp` is an arbitary time of the generation or change
#     - `event_type` is either `change` or `new`
#     - `new_name` and `old_name` will be the same for `new` events, and will vary if the name has changed.

# %%
from itertools import count
from scipy import stats
numb_users = count()

@makeprng
def name_stream(mu, names_str, N=10, p=0.85, prng=None, seed=None):
    random.seed(seed)
    nusers = 0
    dic_names = {}
    poiss = makedist(stats.poisson, prng=prng, mu = mu)

    while True:
        if nusers < N: 
            nusers = next(numb_users)
            offset, = poiss.rvs(size = 1)
            name = next(names_str)
            y = ('new', name, name)
            dic_names[nusers]= name[0]

        else:
            offset, = poiss.rvs(size = 1)
            rand = random.random()
            ## this is cycling after change events. 
            print(rand)
            if rand < p:
                nusers = next(numb_users)
                name = next(names_str)
                y = ('new', name, name)
                dic_names[nusers]= name[0]
            else:
                to_edit = prng.randint(0, nusers)
                print("to edit", to_edit, sep = " ")
                new_name = surname_change(old_name = dic_names[to_edit], males = male_names, seed = 989)
                y = ('change', (new_name, dic_names[to_edit]))
                dic_names[to_edit] = new_name

        yield (offset, y)

# %%
name = names(males = male_names, females = female_names, dist = 0.5, seed=123) # this is a name generator
sim= name_stream(mu=3, names_str = name, N=10, p=0.85, seed=143)

# %%
for i in range(200):
    print(next(sim))
# Out:
# 0.052363598850944326
# (3, ('new', ('Herbjartur Kolfinnurson',), ('Herbjartur Kolfinnurson',)))
# 0.08718667752263232
# (5, ('new', ('Hákun Hervarðurson',), ('Hákun Hervarðurson',)))
# 0.4072417636703983
# (4, ('new', ('Sólmundur Benadiktson',), ('Sólmundur Benadiktson',)))
# 0.10770023493843905
# (2, ('new', ('Niklái Aleksson',), ('Niklái Aleksson',)))
# 0.9011988779516946
# (4, ('new', ('Brá Bergurdóttir',), ('Brá Bergurdóttir',)))
# 0.0381536661023224
# (3, ('new', ('Eyðbjartur Matsson',), ('Eyðbjartur Matsson',)))
# 0.5362020400339269
# (0, ('new', ('Berta Snævardóttir',), ('Berta Snævardóttir',)))
# 0.33219769850967984
# (3, ('new', ('Pál Birgarson',), ('Pál Birgarson',)))
# 0.8520866189293687
# (4, ('new', ('Ata Arnbjørndóttir',), ('Ata Arnbjørndóttir',)))
# 0.1596623967219699
# (3, ('new', ('Eyðsvein Liasson',), ('Eyðsvein Liasson',)))
# 0.3372166571092755
# (3, ('new', ('Hørður Bessison',), ('Hørður Bessison',)))
# 0.3337963946289553
# 0.24516335251761112
# (3, ('new', ('Valdi Hannisson',), ('Valdi Hannisson',)))
# 0.0016705535792228554
# 0.4362757934152184
# (3, ('new', ('Ingivaldur Fríðmundurson',), ('Ingivaldur Fríðmundurson',)))
# 0.08761349975042287
# 0.5975994644879905
# (3, ('new', ('Eyðbjørt Oddgeirdóttir',), ('Eyðbjørt Oddgeirdóttir',)))
# 0.06987696145918243
# 0.3154589737358633
# (2, ('new', ('Tóroddur Ásbrandurson',), ('Tóroddur Ásbrandurson',)))
# 0.44832170830694373
# 0.9053986522844989
# (2, ('new', ('Laila Tótidóttir',), ('Laila Tótidóttir',)))
# 0.09276456137849509
# 0.14217506443150107
# (0, ('new', ('Hannus Ábramson',), ('Hannus Ábramson',)))
# 0.7900718443588016
# 0.021235974816989245
# (1, ('new', ('Hákun Ápramson',), ('Hákun Ápramson',)))
# 0.9111505480903207
# to edit 1
# (6, ('change', ('Hákun Hallgrímurson', 'Hákun Hervarðurson')))
# 0.7821524079157388
# 0.2992181251323298
# (1, ('new', ('Mannbjørn Nikodemusson',), ('Mannbjørn Nikodemusson',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Djóni Kjartanson',), ('Djóni Kjartanson',)))
# 0.666311599621751
# 0.7181566886881766
# (1, ('new', ('Billa Borgardóttir',), ('Billa Borgardóttir',)))
# 0.8694271457220869
# to edit 2
# (0, ('change', ('Sólmundur Hallgrímurson', 'Sólmundur Benadiktson')))
# 0.7821524079157388
# 0.2992181251323298
# (1, ('new', ('Vilbergur Herolvurson',), ('Vilbergur Herolvurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (4, ('new', ('Hemingur Edvardson',), ('Hemingur Edvardson',)))
# 0.666311599621751
# 0.7181566886881766
# (4, ('new', ('Eyðhild Villidóttir',), ('Eyðhild Villidóttir',)))
# 0.8694271457220869
# to edit 15
# (2, ('change', ('Laila Hallgrímurdóttir', 'Laila Tótidóttir')))
# 0.7821524079157388
# 0.2992181251323298
# (4, ('new', ('Vilhjálmur Ottoson',), ('Vilhjálmur Ottoson',)))
# 0.6972065141708129
# 0.42367482710752224
# (5, ('new', ('Gripur Immanuelson',), ('Gripur Immanuelson',)))
# 0.666311599621751
# 0.7181566886881766
# (2, ('new', ('Sólfríð Napoleondóttir',), ('Sólfríð Napoleondóttir',)))
# 0.8694271457220869
# to edit 14
# (7, ('change', ('Tóroddur Hallgrímurson', 'Tóroddur Ásbrandurson')))
# 0.7821524079157388
# 0.2992181251323298
# (6, ('new', ('Úlvur Bergurson',), ('Úlvur Bergurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (3, ('new', ('Valbergur Melkirson',), ('Valbergur Melkirson',)))
# 0.666311599621751
# 0.7181566886881766
# (3, ('new', ('Jónleyg Ingimardóttir',), ('Jónleyg Ingimardóttir',)))
# 0.8694271457220869
# to edit 10
# (2, ('change', ('Hørður Hallgrímurson', 'Hørður Bessison')))
# 0.7821524079157388
# 0.2992181251323298
# (6, ('new', ('Signheðin Tobiasson',), ('Signheðin Tobiasson',)))
# 0.6972065141708129
# 0.42367482710752224
# (3, ('new', ('Júst Broddison',), ('Júst Broddison',)))
# 0.666311599621751
# 0.7181566886881766
# (9, ('new', ('Jústa Geirolvurdóttir',), ('Jústa Geirolvurdóttir',)))
# 0.8694271457220869
# to edit 31
# (2, ('change', ('Júst Hallgrímurson', 'Júst Broddison')))
# 0.7821524079157388
# 0.2992181251323298
# (2, ('new', ('Dagbjartur Svávarson',), ('Dagbjartur Svávarson',)))
# 0.6972065141708129
# 0.42367482710752224
# (3, ('new', ('Mórits Edvardson',), ('Mórits Edvardson',)))
# 0.666311599621751
# 0.7181566886881766
# (7, ('new', ('Janhild Herbjarturdóttir',), ('Janhild Herbjarturdóttir',)))
# 0.8694271457220869
# to edit 18
# (6, ('change', ('Mannbjørn Hallgrímurson', 'Mannbjørn Nikodemusson')))
# 0.7821524079157388
# 0.2992181251323298
# (0, ('new', ('Sigurð Búison',), ('Sigurð Búison',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Teinar Hjalmarson',), ('Teinar Hjalmarson',)))
# 0.666311599621751
# 0.7181566886881766
# (2, ('new', ('Froydis Fríðrikurdóttir',), ('Froydis Fríðrikurdóttir',)))
# 0.8694271457220869
# to edit 7
# (2, ('change', ('Pál Hallgrímurson', 'Pál Birgarson')))
# 0.7821524079157388
# 0.2992181251323298
# (5, ('new', ('Bjørgúlvur Hemmingurson',), ('Bjørgúlvur Hemmingurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (5, ('new', ('Einar Magnison',), ('Einar Magnison',)))
# 0.666311599621751
# 0.7181566886881766
# (4, ('new', ('Steinvør Helgidóttir',), ('Steinvør Helgidóttir',)))
# 0.8694271457220869
# to edit 29
# (2, ('change', ('Jónleyg Hallgrímurdóttir', 'Jónleyg Ingimardóttir')))
# 0.7821524079157388
# 0.2992181251323298
# (5, ('new', ('Jan Lávusson',), ('Jan Lávusson',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Gunnálvur Tráinson',), ('Gunnálvur Tráinson',)))
# 0.666311599621751
# 0.7181566886881766
# (3, ('new', ('Mirjam Sørkvidóttir',), ('Mirjam Sørkvidóttir',)))
# 0.8694271457220869
# to edit 26
# (2, ('change', ('Sólfríð Hallgrímurdóttir', 'Sólfríð Napoleondóttir')))
# 0.7821524079157388
# 0.2992181251323298
# (4, ('new', ('Konrad Jónasson',), ('Konrad Jónasson',)))
# 0.6972065141708129
# 0.42367482710752224
# (5, ('new', ('Ørvar Arngrímurson',), ('Ørvar Arngrímurson',)))
# 0.666311599621751
# 0.7181566886881766
# (4, ('new', ('Hansina Sprotidóttir',), ('Hansina Sprotidóttir',)))
# 0.8694271457220869
# to edit 29
# (2, ('change', ('Jónleyg Hallgrímurdóttir', 'Jónleyg Hallgrímurdóttir')))
# 0.7821524079157388
# 0.2992181251323298
# (1, ('new', ('Hanus Arnoddurson',), ('Hanus Arnoddurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (1, ('new', ('Ásbjørn Korneliusson',), ('Ásbjørn Korneliusson',)))
# 0.666311599621751
# 0.7181566886881766
# (7, ('new', ('Sirið Brandurdóttir',), ('Sirið Brandurdóttir',)))
# 0.8694271457220869
# to edit 41
# (6, ('change', ('Steinvør Hallgrímurdóttir', 'Steinvør Helgidóttir')))
# 0.7821524079157388
# 0.2992181251323298
# (4, ('new', ('Óðin Jónsteinson',), ('Óðin Jónsteinson',)))
# 0.6972065141708129
# 0.42367482710752224
# (5, ('new', ('Heindrikur Jústinusson',), ('Heindrikur Jústinusson',)))
# 0.666311599621751
# 0.7181566886881766
# (6, ('new', ('Gloria Absalondóttir',), ('Gloria Absalondóttir',)))
# 0.8694271457220869
# to edit 1
# (4, ('change', ('Hákun Hallgrímurson', 'Hákun Hallgrímurson')))
# 0.7821524079157388
# 0.2992181251323298
# (3, ('new', ('Eyðolvur Steintórson',), ('Eyðolvur Steintórson',)))
# 0.6972065141708129
# 0.42367482710752224
# (1, ('new', ('Geir Gabrielson',), ('Geir Gabrielson',)))
# 0.666311599621751
# 0.7181566886881766
# (2, ('new', ('Aleksandra Baldurdóttir',), ('Aleksandra Baldurdóttir',)))
# 0.8694271457220869
# to edit 21
# (3, ('change', ('Vilbergur Hallgrímurson', 'Vilbergur Herolvurson')))
# 0.7821524079157388
# 0.2992181251323298
# (3, ('new', ('Elmar Jónfinnurson',), ('Elmar Jónfinnurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (0, ('new', ('Jarmundur Brendanson',), ('Jarmundur Brendanson',)))
# 0.666311599621751
# 0.7181566886881766
# (4, ('new', ('Jónvør Leivurdóttir',), ('Jónvør Leivurdóttir',)))
# 0.8694271457220869
# to edit 16
# (2, ('change', ('Hannus Hallgrímurson', 'Hannus Ábramson')))
# 0.7821524079157388
# 0.2992181251323298
# (8, ('new', ('Vagnur Yngvarson',), ('Vagnur Yngvarson',)))
# 0.6972065141708129
# 0.42367482710752224
# (3, ('new', ('Ottar Vilmarson',), ('Ottar Vilmarson',)))
# 0.666311599621751
# 0.7181566886881766
# (1, ('new', ('Emilia Benjamindóttir',), ('Emilia Benjamindóttir',)))
# 0.8694271457220869
# to edit 55
# (3, ('change', ('Geir Hallgrímurson', 'Geir Gabrielson')))
# 0.7821524079157388
# 0.2992181251323298
# (4, ('new', ('Jørmundur Tormóðurson',), ('Jørmundur Tormóðurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Pól Albinson',), ('Pól Albinson',)))
# 0.666311599621751
# 0.7181566886881766
# (3, ('new', ('Bjarnfríð Hendrikurdóttir',), ('Bjarnfríð Hendrikurdóttir',)))
# 0.8694271457220869
# to edit 59
# (6, ('change', ('Jónvør Hallgrímurdóttir', 'Jónvør Leivurdóttir')))
# 0.7821524079157388
# 0.2992181251323298
# (5, ('new', ('Arnar Ávaldurson',), ('Arnar Ávaldurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (1, ('new', ('Gustav Geirolvurson',), ('Gustav Geirolvurson',)))
# 0.666311599621751
# 0.7181566886881766
# (7, ('new', ('Julianna Gudmardóttir',), ('Julianna Gudmardóttir',)))
# 0.8694271457220869
# to edit 10
# (3, ('change', ('Hørður Hallgrímurson', 'Hørður Hallgrímurson')))
# 0.7821524079157388
# 0.2992181251323298
# (2, ('new', ('Jallgrímur Gulakurson',), ('Jallgrímur Gulakurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Ingimundur Sveinurson',), ('Ingimundur Sveinurson',)))
# 0.666311599621751
# 0.7181566886881766
# (2, ('new', ('Maifríð Hildibjarturdóttir',), ('Maifríð Hildibjarturdóttir',)))
# 0.8694271457220869
# to edit 12
# (2, ('change', ('Ingivaldur Hallgrímurson', 'Ingivaldur Fríðmundurson')))
# 0.7821524079157388
# 0.2992181251323298
# (3, ('new', ('Hagbarður Arnsveinson',), ('Hagbarður Arnsveinson',)))
# 0.6972065141708129
# 0.42367482710752224
# (3, ('new', ('Sveinbjørn Ørnolvurson',), ('Sveinbjørn Ørnolvurson',)))
# 0.666311599621751
# 0.7181566886881766
# (3, ('new', ('Signuva Halgirdóttir',), ('Signuva Halgirdóttir',)))
# 0.8694271457220869
# to edit 15
# (5, ('change', ('Laila Hallgrímurdóttir', 'Laila Hallgrímurdóttir')))
# 0.7821524079157388
# 0.2992181251323298
# (3, ('new', ('Bresti Baldvinson',), ('Bresti Baldvinson',)))
# 0.6972065141708129
# 0.42367482710752224
# (3, ('new', ('Herbert Ímundurson',), ('Herbert Ímundurson',)))
# 0.666311599621751
# 0.7181566886881766
# (4, ('new', ('Hjalma Gylvidóttir',), ('Hjalma Gylvidóttir',)))
# 0.8694271457220869
# to edit 62
# (6, ('change', ('Emilia Hallgrímurdóttir', 'Emilia Benjamindóttir')))
# 0.7821524079157388
# 0.2992181251323298
# (6, ('new', ('Kaleb Ovison',), ('Kaleb Ovison',)))
# 0.6972065141708129
# 0.42367482710752224
# (1, ('new', ('Hermóður Julianson',), ('Hermóður Julianson',)))
# 0.666311599621751
# 0.7181566886881766
# (1, ('new', ('Lotta Ingvaldurdóttir',), ('Lotta Ingvaldurdóttir',)))
# 0.8694271457220869
# to edit 27
# (1, ('change', ('Úlvur Hallgrímurson', 'Úlvur Bergurson')))
# 0.7821524079157388
# 0.2992181251323298
# (2, ('new', ('Súnmundur Ørnolvurson',), ('Súnmundur Ørnolvurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Jørmundur Arnórson',), ('Jørmundur Arnórson',)))
# 0.666311599621751
# 0.7181566886881766
# (3, ('new', ('Agnas Ásmóðurdóttir',), ('Agnas Ásmóðurdóttir',)))
# 0.8694271457220869
# to edit 45
# (4, ('change', ('Konrad Hallgrímurson', 'Konrad Jónasson')))
# 0.7821524079157388
# 0.2992181251323298
# (7, ('new', ('Hjalmar Esbernson',), ('Hjalmar Esbernson',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Eyðolvur Ásarson',), ('Eyðolvur Ásarson',)))
# 0.666311599621751
# 0.7181566886881766
# (3, ('new', ('Oda Elmardóttir',), ('Oda Elmardóttir',)))
# 0.8694271457220869
# to edit 26
# (5, ('change', ('Sólfríð Hallgrímurdóttir', 'Sólfríð Hallgrímurdóttir')))
# 0.7821524079157388
# 0.2992181251323298
# (6, ('new', ('Jóhannis Ásleivurson',), ('Jóhannis Ásleivurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (1, ('new', ('Jøkil Róarson',), ('Jøkil Róarson',)))
# 0.666311599621751
# 0.7181566886881766
# (0, ('new', ('Margret Oyolvurdóttir',), ('Margret Oyolvurdóttir',)))
# 0.8694271457220869
# to edit 87
# (3, ('change', ('Jóhannis Hallgrímurson', 'Jóhannis Ásleivurson')))
# 0.7821524079157388
# 0.2992181251323298
# (5, ('new', ('Sørli Borgarson',), ('Sørli Borgarson',)))
# 0.6972065141708129
# 0.42367482710752224
# (1, ('new', ('Sunnleivur Ísmalson',), ('Sunnleivur Ísmalson',)))
# 0.666311599621751
# 0.7181566886881766
# (2, ('new', ('Torvør Frímanndóttir',), ('Torvør Frímanndóttir',)))
# 0.8694271457220869
# to edit 33
# (2, ('change', ('Dagbjartur Hallgrímurson', 'Dagbjartur Svávarson')))
# 0.7821524079157388
# 0.2992181251323298
# (2, ('new', ('Esbern Rósingurson',), ('Esbern Rósingurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (3, ('new', ('Jónleivur Jaspurson',), ('Jónleivur Jaspurson',)))
# 0.666311599621751
# 0.7181566886881766
# (3, ('new', ('Magga Meinharddóttir',), ('Magga Meinharddóttir',)))
# 0.8694271457220869
# to edit 18
# (3, ('change', ('Mannbjørn Hallgrímurson', 'Mannbjørn Hallgrímurson')))
# 0.7821524079157388
# 0.2992181251323298
# (3, ('new', ('Aleks Korneliusson',), ('Aleks Korneliusson',)))
# 0.6972065141708129
# 0.42367482710752224
# (1, ('new', ('Steinfinnur Baldvinson',), ('Steinfinnur Baldvinson',)))
# 0.666311599621751
# 0.7181566886881766
# (4, ('new', ('Erika Eyðbjørndóttir',), ('Erika Eyðbjørndóttir',)))
# 0.8694271457220869
# to edit 18
# (3, ('change', ('Mannbjørn Hallgrímurson', 'Mannbjørn Hallgrímurson')))
# 0.7821524079157388
# 0.2992181251323298
# (5, ('new', ('Marius Oddleivurson',), ('Marius Oddleivurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Bjørn Helgison',), ('Bjørn Helgison',)))
# 0.666311599621751
# 0.7181566886881766
# (1, ('new', ('Oddný Reimardóttir',), ('Oddný Reimardóttir',)))
# 0.8694271457220869
# to edit 6
# (3, ('change', ('Berta Hallgrímurdóttir', 'Berta Snævardóttir')))
# 0.7821524079157388
# 0.2992181251323298
# (2, ('new', ('Jósef Laarsson',), ('Jósef Laarsson',)))
# 0.6972065141708129
# 0.42367482710752224
# (4, ('new', ('Ketil Rúnolvurson',), ('Ketil Rúnolvurson',)))
# 0.666311599621751
# 0.7181566886881766
# (2, ('new', ('Paulina Áskildóttir',), ('Paulina Áskildóttir',)))
# 0.8694271457220869
# to edit 85
# (2, ('change', ('Eyðolvur Hallgrímurson', 'Eyðolvur Ásarson')))
# 0.7821524079157388
# 0.2992181251323298
# (2, ('new', ('Ragnvaldur Sigbjarturson',), ('Ragnvaldur Sigbjarturson',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Bárður Høskuldurson',), ('Bárður Høskuldurson',)))
# 0.666311599621751
# 0.7181566886881766
# (2, ('new', ('Oddný Jóhannesdóttir',), ('Oddný Jóhannesdóttir',)))
# 0.8694271457220869
# to edit 94
# (3, ('change', ('Jónleivur Hallgrímurson', 'Jónleivur Jaspurson')))
# 0.7821524079157388
# 0.2992181251323298
# (4, ('new', ('Játmundur Oymundurson',), ('Játmundur Oymundurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (1, ('new', ('Høgnar Eindrison',), ('Høgnar Eindrison',)))
# 0.666311599621751
# 0.7181566886881766
# (3, ('new', ('Vónbjørt Gíslidóttir',), ('Vónbjørt Gíslidóttir',)))
# 0.8694271457220869
# to edit 70
# (2, ('change', ('Ingimundur Hallgrímurson', 'Ingimundur Sveinurson')))
# 0.7821524079157388
# 0.2992181251323298
# (0, ('new', ('Onundur Jatmundurson',), ('Onundur Jatmundurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (7, ('new', ('Fróðar Knúturson',), ('Fróðar Knúturson',)))
# 0.666311599621751
# 0.7181566886881766
# (1, ('new', ('Svanna Oddmundurdóttir',), ('Svanna Oddmundurdóttir',)))
# 0.8694271457220869
# to edit 16
# (3, ('change', ('Hannus Hallgrímurson', 'Hannus Hallgrímurson')))
# 0.7821524079157388
# 0.2992181251323298
# (2, ('new', ('Kálvur Hansson',), ('Kálvur Hansson',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Gunnstein Jákupson',), ('Gunnstein Jákupson',)))
# 0.666311599621751
# 0.7181566886881766
# (6, ('new', ('Roda Vigfúsdóttir',), ('Roda Vigfúsdóttir',)))
# 0.8694271457220869
# to edit 37
# (2, ('change', ('Teinar Hallgrímurson', 'Teinar Hjalmarson')))
# 0.7821524079157388
# 0.2992181251323298
# (6, ('new', ('Betuel Hallbjørnson',), ('Betuel Hallbjørnson',)))
# 0.6972065141708129
# 0.42367482710752224
# (1, ('new', ('Mattias Gunnsteinson',), ('Mattias Gunnsteinson',)))
# 0.666311599621751
# 0.7181566886881766
# (2, ('new', ('Emilý Rafaeldóttir',), ('Emilý Rafaeldóttir',)))
# 0.8694271457220869
# to edit 39
# (1, ('change', ('Bjørgúlvur Hallgrímurson', 'Bjørgúlvur Hemmingurson')))
# 0.7821524079157388
# 0.2992181251323298
# (3, ('new', ('Ásfinnur Rógvison',), ('Ásfinnur Rógvison',)))
# 0.6972065141708129
# 0.42367482710752224
# (1, ('new', ('Hjartvar Oysteinson',), ('Hjartvar Oysteinson',)))
# 0.666311599621751
# 0.7181566886881766
# (3, ('new', ('Gerda Esekieldóttir',), ('Gerda Esekieldóttir',)))
# 0.8694271457220869
# to edit 60
# (1, ('change', ('Vagnur Hallgrímurson', 'Vagnur Yngvarson')))
# 0.7821524079157388
# 0.2992181251323298
# (3, ('new', ('Hákun Leoson',), ('Hákun Leoson',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Sólbjørn Aggusteinusson',), ('Sólbjørn Aggusteinusson',)))
# 0.666311599621751
# 0.7181566886881766
# (2, ('new', ('Unnur Syftundóttir',), ('Unnur Syftundóttir',)))
# 0.8694271457220869
# to edit 71
# (6, ('change', ('Maifríð Hallgrímurdóttir', 'Maifríð Hildibjarturdóttir')))
# 0.7821524079157388
# 0.2992181251323298
# (3, ('new', ('Skofti Tókison',), ('Skofti Tókison',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Gripur Sámalson',), ('Gripur Sámalson',)))
# 0.666311599621751
# 0.7181566886881766
# (2, ('new', ('Havdis Gudfinnurdóttir',), ('Havdis Gudfinnurdóttir',)))
# 0.8694271457220869
# to edit 84
# (2, ('change', ('Hjalmar Hallgrímurson', 'Hjalmar Esbernson')))
# 0.7821524079157388
# 0.2992181251323298
# (2, ('new', ('Vígbaldur Vigfússon',), ('Vígbaldur Vigfússon',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Hórður Róarson',), ('Hórður Róarson',)))
# 0.666311599621751
# 0.7181566886881766
# (2, ('new', ('Emilý Einardóttir',), ('Emilý Einardóttir',)))
# 0.8694271457220869
# to edit 114
# (7, ('change', ('Kálvur Hallgrímurson', 'Kálvur Hansson')))
# 0.7821524079157388
# 0.2992181251323298
# (5, ('new', ('Aggusteinus Gulakurson',), ('Aggusteinus Gulakurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (5, ('new', ('Stígur Bótolvurson',), ('Stígur Bótolvurson',)))
# 0.666311599621751
# 0.7181566886881766
# (4, ('new', ('Ingileyg Gíslidóttir',), ('Ingileyg Gíslidóttir',)))
# 0.8694271457220869
# to edit 17
# (3, ('change', ('Hákun Hallgrímurson', 'Hákun Ápramson')))
# 0.7821524079157388
# 0.2992181251323298
# (4, ('new', ('Oskar Mikalson',), ('Oskar Mikalson',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Kristin Hagbarðurson',), ('Kristin Hagbarðurson',)))
# 0.666311599621751
# 0.7181566886881766
# (4, ('new', ('Finngerð Jóeldóttir',), ('Finngerð Jóeldóttir',)))
# 0.8694271457220869
# to edit 73
# (1, ('change', ('Sveinbjørn Hallgrímurson', 'Sveinbjørn Ørnolvurson')))
# 0.7821524079157388
# 0.2992181251323298
# (2, ('new', ('Eyðmar Rómundurson',), ('Eyðmar Rómundurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (7, ('new', ('Bragi Ingmarson',), ('Bragi Ingmarson',)))
# 0.666311599621751
# 0.7181566886881766
# (6, ('new', ('Malan Dáviddóttir',), ('Malan Dáviddóttir',)))
# 0.8694271457220869
# to edit 26
# (5, ('change', ('Sólfríð Hallgrímurdóttir', 'Sólfríð Hallgrímurdóttir')))
# 0.7821524079157388
# 0.2992181251323298
# (3, ('new', ('Klæmint Hallbergurson',), ('Klæmint Hallbergurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Sonni Eyðbjørnson',), ('Sonni Eyðbjørnson',)))
# 0.666311599621751
# 0.7181566886881766
# (3, ('new', ('Rebekka Húnbogidóttir',), ('Rebekka Húnbogidóttir',)))
# 0.8694271457220869
# to edit 67
# (4, ('change', ('Gustav Hallgrímurson', 'Gustav Geirolvurson')))
# 0.7821524079157388
# 0.2992181251323298
# (5, ('new', ('Arinbjørn Tórolvurson',), ('Arinbjørn Tórolvurson',)))
# 0.6972065141708129
# 0.42367482710752224
# (6, ('new', ('Hannis Nóison',), ('Hannis Nóison',)))
# 0.666311599621751
# 0.7181566886881766
# (3, ('new', ('Jóanna Hámundurdóttir',), ('Jóanna Hámundurdóttir',)))
# 0.8694271457220869
# to edit 135
# (4, ('change', ('Oskar Hallgrímurson', 'Oskar Mikalson')))
# 0.7821524079157388
# 0.2992181251323298
# (5, ('new', ('Máur Bernarson',), ('Máur Bernarson',)))
# 0.6972065141708129
# 0.42367482710752224
# (2, ('new', ('Fríðálvur Vitusson',), ('Fríðálvur Vitusson',)))
# 0.666311599621751
# 0.7181566886881766
# (1, ('new', ('Aleksandra Summarliðidóttir',), ('Aleksandra Summarliðidóttir',)))
# 0.8694271457220869
# to edit 132
# (4, ('change', ('Aggusteinus Hallgrímurson', 'Aggusteinus Gulakurson')))
# 0.7821524079157388
# 0.2992181251323298
# (1, ('new', ('Tummas Lavarsson',), ('Tummas Lavarsson',)))
# 0.6972065141708129
# 0.42367482710752224
# (4, ('new', ('Nemus Óttarson',), ('Nemus Óttarson',)))
# 0.666311599621751
# 0.7181566886881766
# (1, ('new', ('Fríðrun Steinmundurdóttir',), ('Fríðrun Steinmundurdóttir',)))
# 0.8694271457220869
# to edit 143
# (2, ('change', ('Rebekka Hallgrímurdóttir', 'Rebekka Húnbogidóttir')))
# 0.7821524079157388
# 0.2992181251323298
# (3, ('new', ('Bjørgfinnur Brynleivurson',), ('Bjørgfinnur Brynleivurson',)))
