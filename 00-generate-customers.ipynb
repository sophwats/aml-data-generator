# %% [markdown]
# ## Generating Customers
#
# In this notebook we will build up an event generator for making or changing personally identifiable information (PII) for bank customers.
#
# Each event will either be a `new` customer or a `change` event.
#
# When a `new` event occurs, we will generate a new customer and a set of PII for them including their:
#     - Name
#     - Date of Birth
#     - Social Security number
#     - Bank account details
#
# When a `change` event occurs, we will select an existing customer and alter one piece of their PII.

# %% [markdown]
# #### Making Repeatable Simulations
#
# We follow the methodology laid out [here](https://chapeau.freevariable.com/2020/02/repeatable-simulation-without-boilerplate.html) to ensure that any simulations can be deterministic, and thus repeatable. This is really desirable as it enables us to replay data on new models to test them.

# %%
### Setting up repeatibility
### This is copied directly from Will's notebook
### to do - ? put into a separate file?

def makeprng(func):
    import time
    def call_with_prng(*args, prng=None, seed=None, **kwargs):
        if prng is None:
            if seed is None:
                seed = int(time.time()) & ((1 << 32) - 1)
            prng = np.random.RandomState(seed)
        return func(*args, prng=prng, seed=seed, **kwargs)
    return call_with_prng

#again copied verbatim from Will's notebook. 
#the code makes it really simple to set seeds in the scipy distributions.
def makedist(dist_cls, seed=None, prng=None, **kwargs):
    d = dist_cls(**kwargs)
    d.random_state = (seed and seed) or prng.randint((1 << 32) - 1)
    return d

# %% [markdown]
# ## Simulating Names
#
# We begin by simulating user names. For this notebook we are using a set of Faroese names, which we scrape from a webpage using `BeautifulSoup`. We follow Faroese naming convention -  female surnames end in _dóttir_ whilst male surnames end in _son_.

# %%
## this should be pushed to a different file, and the data sets we generate saved

from bs4 import BeautifulSoup
import random
import numpy as np


with open("data/faroese-female.htm") as ff:
    soup = BeautifulSoup(ff)

names = soup.find_all('a')

female_names = []
for n in names:
    try:
        female_names.append(n['title'].rsplit(' ')[0])
    except Exception:
        pass
del female_names[0]

with open("data/faroese-male.htm") as fm:
    soup = BeautifulSoup(fm)
    
mnames = soup.find_all('a')
male_names = []
for n in mnames:
    try:
        male_names.append(n['title'].rsplit(' ')[0])
    except Exception:
        pass
del male_names[0]

n_male = len(male_names)
n_female = len(female_names)

# %% [markdown]
# In this next cell we set up a generator which simulates names from the set we scraped above.

# %%
## this isn't computing the generative form of the male names. 
@makeprng
def names(males, females, dist=0.5, prng=None, seed=None):
    
    n_male = len(males)
    n_female = len(females)


    while True:
        rand = prng.random_sample()
        surname = males[prng.randint(0, n_male-1)]
        if rand < dist:
            gender = 'male'
            first_name = males[prng.randint(0, n_male-1)]
            surname = surname + 'son'
        else:
            first_name = females[prng.randint(0, n_female-1)]
            surname = surname + 'dóttir'
            gender = 'female'
            
        result = " ".join([first_name,surname])
        yield result
        
name = names(males = male_names, females = female_names, dist = 0.5, seed=123) # this is a name generator

# %%
for i in range(10):
    print(next(name))
# Out:
# Hera Hervarðurdóttir
# Aleks Sólmundurson
# Oygló Bjartidóttir
# Bjørg Beinidóttir
# Lias Áskilson
# Hørður Bessison
# Ingivaldur Fríðmundurson
# Tóroddur Ásbrandurson
# Hannus Ábramson
# Oddvá Nikodemusdóttir

# %% [markdown]
# ## Change events
#
# Before we generating more PII, we set up a simple `surname_change` function. At the moment this function simply selects a customer at random and changes their surname.

# %%
@makeprng
def surname_change(old_name, males, prng=None, seed=None):
    ## takes in old name
    ## assumes name is of the form 'first name, surname'
    surname = males[prng.randint(0, n_male-1)]
    
    ## checks to see if male or female. 
    if 'dóttir' in old_name:
        surname = surname + 'dóttir'
        
    else:
        surname = surname + 'son'
    
    new_name = " ".join([old_name.split()[0], surname])
    return new_name

# %% [markdown]
# ## Customer generator
#
# We now have enough functionality to make a basic customer generator. The generator will first create `N` new users. Once `N` users have been created each subsequent event will:
#     - generate another new user with probability `p`
#     - change the surname of an existing user with probability `1-p`
#
# Events take the form `(timestamp, (event_type, (new_name, old_name)))` where
#     - `timestamp` is an arbitary time of the generation or change
#     - `event_type` is either `change` or `new`
#     - `new_name` and `old_name` will be the same for `new` events, and will vary if the name has changed.

# %%
from itertools import count
from scipy import stats
numb_users = count()

@makeprng
def name_stream(mu, names_str, N=10, p=0.85, prng=None, seed=None):
    nusers = 0
    dic_names = {}
    poiss = makedist(stats.poisson, prng=prng, mu = mu)
    prng = np.random.RandomState(seed or 0xda7aba5e)

    while True:
        if nusers < N: 
            nusers = next(numb_users)
            offset = poiss.rvs()
            name = next(names_str)
            y = ('new', name, name)
            dic_names[nusers]= name

        else:
            offset = poiss.rvs()
            rand = prng.random_sample()

            if rand < p:
                nusers = next(numb_users)
                name = next(names_str)
                y = ('new', name, name)
                dic_names[nusers]= name
            else:
                to_edit = prng.randint(0, nusers)
                new_name = surname_change(old_name = dic_names[to_edit], males = male_names, prng=prng)
                y = ('change', new_name, dic_names[to_edit])
                dic_names[to_edit] = new_name
                
        
        yield (offset, y)

# %%
name = names(males = male_names, females = female_names, dist = 0.5, seed=123) # this is a name generator
sim= name_stream(mu=3, names_str = name, N=10, p=0.85, seed=143)

# %%
for i in range(200):
    print(next(sim))
# Out:
# (3, ('new', 'Hera Hervarðurdóttir', 'Hera Hervarðurdóttir'))
# (5, ('new', 'Aleks Sólmundurson', 'Aleks Sólmundurson'))
# (4, ('new', 'Oygló Bjartidóttir', 'Oygló Bjartidóttir'))
# (2, ('new', 'Bjørg Beinidóttir', 'Bjørg Beinidóttir'))
# (4, ('new', 'Lias Áskilson', 'Lias Áskilson'))
# (3, ('new', 'Hørður Bessison', 'Hørður Bessison'))
# (0, ('new', 'Ingivaldur Fríðmundurson', 'Ingivaldur Fríðmundurson'))
# (3, ('new', 'Tóroddur Ásbrandurson', 'Tóroddur Ásbrandurson'))
# (4, ('new', 'Hannus Ábramson', 'Hannus Ábramson'))
# (3, ('new', 'Oddvá Nikodemusdóttir', 'Oddvá Nikodemusdóttir'))
# (3, ('new', 'Dagfríð Djónidóttir', 'Dagfríð Djónidóttir'))
# (3, ('new', 'Ella Herolvurdóttir', 'Ella Herolvurdóttir'))
# (3, ('new', 'Otto Eyðálvurson', 'Otto Eyðálvurson'))
# (3, ('new', 'Napoleon Gripurson', 'Napoleon Gripurson'))
# (2, ('new', 'Pálma Bergurdóttir', 'Pálma Bergurdóttir'))
# (2, ('new', 'Hjálmar Tristanson', 'Hjálmar Tristanson'))
# (0, ('change', ('Napoleon Oddbjørnson', 'Napoleon Gripurson')))
# (1, ('new', 'Júst Broddison', 'Júst Broddison'))
# (6, ('new', 'Týra Immanueldóttir', 'Týra Immanueldóttir'))
# (1, ('new', 'Poula Edvarddóttir', 'Poula Edvarddóttir'))
# (2, ('change', ('Dagfríð Ernstdóttir', 'Dagfríð Djónidóttir')))
# (1, ('new', 'Sigurð Búison', 'Sigurð Búison'))
# (0, ('change', ('Hjálmar Eskilson', 'Hjálmar Tristanson')))
# (1, ('change', ('Napoleon Robertson', 'Napoleon Oddbjørnson')))
# (4, ('new', 'Flæmingur Fríðrikurson', 'Flæmingur Fríðrikurson'))
# (4, ('new', 'Oddgerð Bjørgúlvurdóttir', 'Oddgerð Bjørgúlvurdóttir'))
# (2, ('new', 'Lávus Sámalson', 'Lávus Sámalson'))
# (4, ('new', 'Gunnálvur Tráinson', 'Gunnálvur Tráinson'))
# (5, ('change', ('Oddgerð Bastiandóttir', 'Oddgerð Bjørgúlvurdóttir')))
# (2, ('change', ('Hørður Sunnleivurson', 'Hørður Bessison')))
# (7, ('new', 'Konrad Jónasson', 'Konrad Jónasson'))
# (6, ('new', 'Sproti Ørvarson', 'Sproti Ørvarson'))
# (3, ('new', 'Kornelius Hanusson', 'Kornelius Hanusson'))
# (3, ('new', 'Lovisa Ríkaldurdóttir', 'Lovisa Ríkaldurdóttir'))
# (2, ('change', ('Bjørg Borgardóttir', 'Bjørg Beinidóttir')))
# (6, ('new', 'Absalon Heindrikurson', 'Absalon Heindrikurson'))
# (3, ('new', 'Fía Steintórdóttir', 'Fía Steintórdóttir'))
# (9, ('new', 'Aleksandra Baldurdóttir', 'Aleksandra Baldurdóttir'))
# (2, ('change', ('Absalon Húnison', 'Absalon Heindrikurson')))
# (2, ('new', 'Dania Elmardóttir', 'Dania Elmardóttir'))
# (3, ('new', 'Hórður Tórhallurson', 'Hórður Tórhallurson'))
# (7, ('new', 'Salvør Vagnurdóttir', 'Salvør Vagnurdóttir'))
# (6, ('new', 'Malja Tormóðurdóttir', 'Malja Tormóðurdóttir'))
# (0, ('new', 'Bjarnfríð Hendrikurdóttir', 'Bjarnfríð Hendrikurdóttir'))
# (2, ('new', 'Gustav Geirolvurson', 'Gustav Geirolvurson'))
# (2, ('new', 'Klara Gulakurdóttir', 'Klara Gulakurdóttir'))
# (2, ('change', ('Bjørg Eliasdóttir', 'Bjørg Borgardóttir')))
# (5, ('new', 'Maifríð Hildibjarturdóttir', 'Maifríð Hildibjarturdóttir'))
# (5, ('new', 'Sveinbjørn Ørnolvurson', 'Sveinbjørn Ørnolvurson'))
# (4, ('new', 'Torri Torleygurson', 'Torri Torleygurson'))
# (2, ('new', 'Daniella Baldvindóttir', 'Daniella Baldvindóttir'))
# (5, ('new', 'Hjalma Gylvidóttir', 'Hjalma Gylvidóttir'))
# (2, ('new', 'Julian Kalebson', 'Julian Kalebson'))
# (3, ('new', 'Ørnolvur Jonnson', 'Ørnolvur Jonnson'))
# (2, ('new', 'Jørmundur Arnórson', 'Jørmundur Arnórson'))
# (4, ('new', 'Hjalmar Esbernson', 'Hjalmar Esbernson'))
# (5, ('new', 'Lykkir Elmarson', 'Lykkir Elmarson'))
# (4, ('new', 'Jóhannis Ásleivurson', 'Jóhannis Ásleivurson'))
# (2, ('new', 'Kári Oyolvurson', 'Kári Oyolvurson'))
# (1, ('new', 'Trina Ísmaldóttir', 'Trina Ísmaldóttir'))
# (1, ('change', ('Dagfríð Vilbergurdóttir', 'Dagfríð Ernstdóttir')))
# (7, ('new', 'Eyð Rósingurdóttir', 'Eyð Rósingurdóttir'))
# (6, ('new', 'Júlian Meinhardson', 'Júlian Meinhardson'))
# (4, ('new', 'Steinfinnur Baldvinson', 'Steinfinnur Baldvinson'))
# (5, ('new', 'Olga Oddleivurdóttir', 'Olga Oddleivurdóttir'))
# (6, ('new', 'Oddný Reimardóttir', 'Oddný Reimardóttir'))
# (4, ('new', 'Jósef Laarsson', 'Jósef Laarsson'))
# (3, ('new', 'Ata Ketildóttir', 'Ata Ketildóttir'))
# (1, ('new', 'Sigurbjørg Sigbjarturdóttir', 'Sigurbjørg Sigbjarturdóttir'))
# (2, ('new', 'Oddný Jóhannesdóttir', 'Oddný Jóhannesdóttir'))
# (3, ('new', 'Julia Eindridóttir', 'Julia Eindridóttir'))
# (3, ('new', 'Røskva Jatmundurdóttir', 'Røskva Jatmundurdóttir'))
# (0, ('new', 'Svanna Oddmundurdóttir', 'Svanna Oddmundurdóttir'))
# (4, ('new', 'Jákup Kálvurson', 'Jákup Kálvurson'))
# (2, ('new', 'Roda Vigfúsdóttir', 'Roda Vigfúsdóttir'))
# (8, ('new', 'Gunnstein Betuelson', 'Gunnstein Betuelson'))
# (3, ('new', 'Rógvi Eliasson', 'Rógvi Eliasson'))
# (1, ('new', 'Eyðbjørg Hjartvardóttir', 'Eyðbjørg Hjartvardóttir'))
# (3, ('new', 'Aggusteinus Hákunson', 'Aggusteinus Hákunson'))
# (4, ('new', 'Vinný Syftundóttir', 'Vinný Syftundóttir'))
# (2, ('change', ('Oddný Hallgrímurdóttir', 'Oddný Jóhannesdóttir')))
# (3, ('new', 'Hallbera Gripurdóttir', 'Hallbera Gripurdóttir'))
# (6, ('new', 'Snjófríð Vígbaldurdóttir', 'Snjófríð Vígbaldurdóttir'))
# (5, ('change', ('Olga Flosidóttir', 'Olga Oddleivurdóttir')))
# (1, ('new', 'Gulakur Eliasson', 'Gulakur Eliasson'))
# (7, ('new', 'Gunngerð Stígurdóttir', 'Gunngerð Stígurdóttir'))
# (3, ('new', 'Hagbarður Oskarson', 'Hagbarður Oskarson'))
# (2, ('new', 'Finngerð Vilmardóttir', 'Finngerð Vilmardóttir'))
# (2, ('new', 'Karla Eyðmardóttir', 'Karla Eyðmardóttir'))
# (2, ('new', 'Jústinus Dávidson', 'Jústinus Dávidson'))
# (2, ('new', 'Torbera Eyðbjørndóttir', 'Torbera Eyðbjørndóttir'))
# (3, ('new', 'Árna Tórolvurdóttir', 'Árna Tórolvurdóttir'))
# (3, ('change', ('Hera Veturliðidóttir', 'Hera Hervarðurdóttir')))
# (3, ('new', 'Hámundur Hannisson', 'Hámundur Hannisson'))
# (5, ('new', 'Paula Bernardóttir', 'Paula Bernardóttir'))
# (3, ('new', 'Summarliði Fríðálvurson', 'Summarliði Fríðálvurson'))
# (3, ('new', 'Tummas Lavarsson', 'Tummas Lavarsson'))
# (4, ('change', ('Oddgerð Gripurdóttir', 'Oddgerð Bastiandóttir')))
# (6, ('new', 'Steinmundur Nemusson', 'Steinmundur Nemusson'))
# (6, ('new', 'Brialdur Bjørgfinnurson', 'Brialdur Bjørgfinnurson'))
# (1, ('new', 'Malla Pálldóttir', 'Malla Pálldóttir'))
# (1, ('new', 'Torgerð Steffandóttir', 'Torgerð Steffandóttir'))
# (1, ('new', 'Dóra Kornusdóttir', 'Dóra Kornusdóttir'))
# (2, ('new', 'Villiam Hildibjarturson', 'Villiam Hildibjarturson'))
# (2, ('new', 'Ingrún Óðindóttir', 'Ingrún Óðindóttir'))
# (3, ('new', 'Maisól Svenningurdóttir', 'Maisól Svenningurdóttir'))
# (4, ('new', 'Tobias Díðrikurson', 'Tobias Díðrikurson'))
# (7, ('new', 'Malvina Hallmardóttir', 'Malvina Hallmardóttir'))
# (2, ('new', 'Belinda Øgmundurdóttir', 'Belinda Øgmundurdóttir'))
# (3, ('new', 'Marianna Ápramdóttir', 'Marianna Ápramdóttir'))
# (5, ('new', 'Ánanias Hallurson', 'Ánanias Hallurson'))
# (6, ('change', ('Hera Ragnardóttir', 'Hera Veturliðidóttir')))
# (1, ('new', 'Dagbjørg Ábrahamdóttir', 'Dagbjørg Ábrahamdóttir'))
# (0, ('new', 'Narvi Rókurson', 'Narvi Rókurson'))
# (3, ('change', ('Trina Loðindóttir', 'Trina Ísmaldóttir')))
# (5, ('change', ('Sigurbjørg Egildóttir', 'Sigurbjørg Sigbjarturdóttir')))
# (1, ('new', 'Jósup Óttarson', 'Jósup Óttarson'))
# (2, ('new', 'Niels Ingálvurson', 'Niels Ingálvurson'))
# (2, ('new', 'Kristbjørg Greipurdóttir', 'Kristbjørg Greipurdóttir'))
# (2, ('new', 'Reiðgunn Ákidóttir', 'Reiðgunn Ákidóttir'))
# (3, ('new', 'Lýðar Bárðurson', 'Lýðar Bárðurson'))
# (3, ('new', 'Dánjal Olgarson', 'Dánjal Olgarson'))
# (3, ('new', 'Magdalena Pallidóttir', 'Magdalena Pallidóttir'))
# (3, ('new', 'Áron Antonson', 'Áron Antonson'))
# (1, ('new', 'Henningur Aronson', 'Henningur Aronson'))
# (4, ('new', 'Hugi Eyðolvurson', 'Hugi Eyðolvurson'))
# (3, ('new', 'Mortan Vilmundurson', 'Mortan Vilmundurson'))
# (5, ('change', ('Aggusteinus Onundurson', 'Aggusteinus Hákunson')))
# (2, ('new', 'Eyðsvein Valdison', 'Eyðsvein Valdison'))
# (1, ('new', 'Brynhild Fróðardóttir', 'Brynhild Fróðardóttir'))
# (3, ('new', 'Hallstein Bjørgfinnurson', 'Hallstein Bjørgfinnurson'))
# (2, ('new', 'Markus Ormurson', 'Markus Ormurson'))
# (4, ('new', 'Eyðsvein Jørmundurson', 'Eyðsvein Jørmundurson'))
# (2, ('new', 'Herbjørn Viktorson', 'Herbjørn Viktorson'))
# (2, ('new', 'Gyða Hermóðurdóttir', 'Gyða Hermóðurdóttir'))
# (2, ('change', ('Maisól Gylvidóttir', 'Maisól Svenningurdóttir')))
# (2, ('new', 'Filippus Snæbjørnson', 'Filippus Snæbjørnson'))
# (2, ('new', 'Bjalla Valdimardóttir', 'Bjalla Valdimardóttir'))
# (3, ('new', 'Morið Bessidóttir', 'Morið Bessidóttir'))
# (4, ('new', 'Torbrandur Veturliðison', 'Torbrandur Veturliðison'))
# (1, ('change', ('Ørnolvur Símeonson', 'Ørnolvur Jonnson')))
# (3, ('new', 'Narvi Hjaltison', 'Narvi Hjaltison'))
# (2, ('new', 'Eyðstein Eyðfinnurson', 'Eyðstein Eyðfinnurson'))
# (0, ('new', 'Jónsvein Albinson', 'Jónsvein Albinson'))
# (7, ('new', 'Hugi Gudfinnurson', 'Hugi Gudfinnurson'))
# (1, ('change', ('Dóra Fálgeirdóttir', 'Dóra Kornusdóttir')))
# (3, ('new', 'Tjóðhild Eldbjørndóttir', 'Tjóðhild Eldbjørndóttir'))
# (2, ('new', 'Greipur Baltasarson', 'Greipur Baltasarson'))
# (2, ('new', 'Hjørtur Birgarson', 'Hjørtur Birgarson'))
# (6, ('new', 'Tórálvur Baltasarson', 'Tórálvur Baltasarson'))
# (2, ('new', 'Adrian Leoson', 'Adrian Leoson'))
# (6, ('new', 'Tóta Jarmundurdóttir', 'Tóta Jarmundurdóttir'))
# (1, ('new', 'Steffan Onundurson', 'Steffan Onundurson'))
# (2, ('change', ('Salvør Beinardóttir', 'Salvør Vagnurdóttir')))
# (1, ('new', 'Bjartur Røgnvaldurson', 'Bjartur Røgnvaldurson'))
# (3, ('new', 'Ninna Eyðsteindóttir', 'Ninna Eyðsteindóttir'))
# (1, ('new', 'Aurora Filippusdóttir', 'Aurora Filippusdóttir'))
# (3, ('new', 'Vinjar Korneliusson', 'Vinjar Korneliusson'))
# (1, ('new', 'Jóanis Janson', 'Jóanis Janson'))
# (3, ('new', 'Hórður Jónfinnurson', 'Hórður Jónfinnurson'))
# (2, ('new', 'Elisabet Enokurdóttir', 'Elisabet Enokurdóttir'))
# (2, ('new', 'Steintór Hildibjørnson', 'Steintór Hildibjørnson'))
# (6, ('new', 'Kristjan Kolbjørnson', 'Kristjan Kolbjørnson'))
# (3, ('new', 'Sproti Ingimundurson', 'Sproti Ingimundurson'))
# (2, ('new', 'Ástrið Orridóttir', 'Ástrið Orridóttir'))
# (2, ('new', 'Randi Mortandóttir', 'Randi Mortandóttir'))
# (2, ('new', 'Randver Jørmundurson', 'Randver Jørmundurson'))
# (2, ('new', 'Halldis Máurdóttir', 'Halldis Máurdóttir'))
# (2, ('new', 'Bryndis Gudleygurdóttir', 'Bryndis Gudleygurdóttir'))
# (2, ('new', 'Frits Sigurðson', 'Frits Sigurðson'))
# (7, ('change', ('Ninna Hjálmardóttir', 'Ninna Eyðsteindóttir')))
# (5, ('new', 'Halldis Syftundóttir', 'Halldis Syftundóttir'))
# (5, ('new', 'Ernst Tyrnirson', 'Ernst Tyrnirson'))
# (4, ('new', 'Amalia Ánaniasdóttir', 'Amalia Ánaniasdóttir'))
# (3, ('new', 'Brynleivur Hallmarson', 'Brynleivur Hallmarson'))
# (4, ('new', 'Tórur Kolbeinson', 'Tórur Kolbeinson'))
# (2, ('new', 'Edmundur Ormarson', 'Edmundur Ormarson'))
# (4, ('new', 'Ragna Ormurdóttir', 'Ragna Ormurdóttir'))
# (1, ('change', ('Hórður Antinesson', 'Hórður Jónfinnurson')))
# (2, ('new', 'Vilborg Andrasdóttir', 'Vilborg Andrasdóttir'))
# (7, ('new', 'Bessi Arnsveinson', 'Bessi Arnsveinson'))
# (6, ('new', 'Mona Jónharddóttir', 'Mona Jónharddóttir'))
# (5, ('new', 'Kristian Bjørgfinnurson', 'Kristian Bjørgfinnurson'))
# (3, ('new', 'Ástrið Gunnolvurdóttir', 'Ástrið Gunnolvurdóttir'))
# (2, ('new', 'Jófríður Kristleivurson', 'Jófríður Kristleivurson'))
# (3, ('new', 'Mortan Hóraldurson', 'Mortan Hóraldurson'))
# (4, ('new', 'Jútta Eldbjørndóttir', 'Jútta Eldbjørndóttir'))
# (5, ('new', 'Bjørt Kristvardóttir', 'Bjørt Kristvardóttir'))
# (6, ('new', 'Líggjas Arnfinnurson', 'Líggjas Arnfinnurson'))
# (3, ('new', 'Artan Gripurson', 'Artan Gripurson'))
# (4, ('new', 'Jófríður Leikison', 'Jófríður Leikison'))
# (5, ('change', ('Magdalena Havsteindóttir', 'Magdalena Pallidóttir')))
# (2, ('new', 'Sigvør Fríðmundurdóttir', 'Sigvør Fríðmundurdóttir'))
# (1, ('new', 'Ingrún Maksdóttir', 'Ingrún Maksdóttir'))
# (4, ('new', 'Danvør Sigmardóttir', 'Danvør Sigmardóttir'))
# (1, ('change', ('Otto Hermundurson', 'Otto Eyðálvurson')))
# (4, ('new', 'Sølva Símundóttir', 'Sølva Símundóttir'))
# (1, ('new', 'Torný Valbjørndóttir', 'Torný Valbjørndóttir'))
# (2, ('change', ('Jústinus Eldbjørnson', 'Jústinus Dávidson')))
# (3, ('new', 'Gyða Tobiasdóttir', 'Gyða Tobiasdóttir'))
