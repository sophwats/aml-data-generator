# %% [markdown]
# ## Generating Customers
#
# In this notebook we will build up an event generator for making or changing personally identifiable information (PII) for bank customers.
#
# Each event will either be a `new` customer or a `change` event.
#
# When a `new` event occurs, we will generate a new customer and a set of PII for them including their:
#     - Name
#     - Date of Birth
#     - Social Security number
#     - Bank account details
#
# When a `change` event occurs, we will select an existing customer and alter one piece of their PII.

# %% [markdown]
# #### Making Repeatable Simulations
#
# We follow the methodology laid out [here](https://chapeau.freevariable.com/2020/02/repeatable-simulation-without-boilerplate.html) to ensure that any simulations can be deterministic, and thus repeatable. This is really desirable as it enables us to replay data on new models to test them.

# %%
### Setting up repeatibility
### This is copied directly from Will's notebook
### to do - ? put into a separate file?

def makeprng(func):
    import time
    def call_with_prng(*args, prng=None, seed=None, **kwargs):
        if prng is None:
            if seed is None:
                seed = int(time.time()) & ((1 << 32) - 1)
            prng = np.random.RandomState(seed)
        return func(*args, prng=prng, seed=seed, **kwargs)
    return call_with_prng

#again copied verbatim from Will's notebook. 
#the code makes it really simple to set seeds in the scipy distributions.
def makedist(dist_cls, seed=None, prng=None, **kwargs):
    d = dist_cls(**kwargs)
    d.random_state = (seed and seed) or prng.randint((1 << 32) - 1)
    return d

# %% [markdown]
# ## Simulating Names
#
# We begin by simulating user names. For this notebook we are using a set of Faroese names, which we scrape from a webpage using `BeautifulSoup`. We follow Faroese naming convention -  female surnames end in _dóttir_ whilst male surnames end in _son_.

# %%
## this should be pushed to a different file, and the data sets we generate saved

from bs4 import BeautifulSoup
import random
import numpy as np


with open("data/faroese-female.htm") as ff:
    soup = BeautifulSoup(ff)

names = soup.find_all('a')

female_names = []
for n in names:
    try:
        female_names.append(n['title'].rsplit(' ')[0])
    except Exception:
        pass
del female_names[0]

with open("data/faroese-male.htm") as fm:
    soup = BeautifulSoup(fm)
    
mnames = soup.find_all('a')
male_names = []
for n in mnames:
    try:
        male_names.append(n['title'].rsplit(' ')[0])
    except Exception:
        pass
del male_names[0]

n_male = len(male_names)
n_female = len(female_names)

# %% [markdown]
# In this next cell we set up a generator which simulates names from the set we scraped above.

# %%
## this isn't computing the generative form of hte male names. 
@makeprng
def names(males, females, dist=0.5, prng=None, seed=None):
    random.seed(seed)
    
    n_male = len(males)
    n_female = len(females)


    while True:
        rand = random.random()
        ## this is cycling about change events. 
        print(rand)
        surname = males[prng.randint(0, n_male-1)]
        if rand < dist:
            gender = 'male'
            first_name = males[prng.randint(0, n_male-1)]
            surname = surname + 'son'
        else:
            first_name = females[prng.randint(0, n_female-1)]
            surname = surname + 'dóttir'
            gender = 'female'
            
        result = {'name':" ".join([first_name,surname]) }
        yield tuple(r for r in result.values())
        
name = names(males = male_names, females = female_names, dist = 0.5, seed=123) # this is a name generator

# %%
for i in range(10):
    print(next(name))
# Out:
# 0.052363598850944326
# ('Herbjartur Kolfinnurson',)
# 0.08718667752263232
# ('Hákun Hervarðurson',)
# 0.4072417636703983
# ('Sólmundur Benadiktson',)
# 0.10770023493843905
# ('Niklái Aleksson',)
# 0.9011988779516946
# ('Brá Bergurdóttir',)
# 0.0381536661023224
# ('Eyðbjartur Matsson',)
# 0.5362020400339269
# ('Berta Snævardóttir',)
# 0.33219769850967984
# ('Pál Birgarson',)
# 0.8520866189293687
# ('Ata Arnbjørndóttir',)
# 0.1596623967219699
# ('Eyðsvein Liasson',)

# %% [markdown]
# ## Change events
#
# Before we generating more PII, we set up a simple `surname_change` function. At the moment this function simply selects a customer at random and changes their surname.

# %%
@makeprng
def surname_change(old_name, males, prng=None, seed=None):
    ## takes in old name
    ## assumes name is of the form 'first name, surname'
    surname = males[prng.randint(0, n_male-1)]
    
    ## checks to see if male or female. 
    if 'dóttir' in old_name:
        surname = surname + 'dóttir'
        
    else:
        surname = surname + 'son'
    
    new_name = " ".join([old_name.split()[0], surname])
    return new_name

# %% [markdown]
# ## Customer generator
#
# We now have enough functionality to make a basic customer generator. The generator will first create `N` new users. Once `N` users have been created each subsequent event will:
#     - generate another new user with probability `p`
#     - change the surname of an existing user with probability `1-p`
#
# Events take the form `(timestamp, (event_type, (new_name, old_name)))` where
#     - `timestamp` is an arbitary time of the generation or change
#     - `event_type` is either `change` or `new`
#     - `new_name` and `old_name` will be the same for `new` events, and will vary if the name has changed.

# %%
from itertools import count
from scipy import stats
numb_users = count()

@makeprng
def name_stream(mu, names_str, N=10, p=0.85, prng=None, seed=None):
    nusers = 0
    dic_names = {}
    poiss = makedist(stats.poisson, prng=prng, mu = mu)
    prng = np.random.RandomState(seed or 0xda7aba5e)
    print(prng)

    while True:
        if nusers < N: 
            nusers = next(numb_users)
            offset, = poiss.rvs(size = 1)
            name = next(names_str)
            y = ('new', name, name)
            dic_names[nusers]= name[0]

        else:
            offset, = poiss.rvs(size = 1)
            rand = prng.random_sample()
            ## this is cycling after change events. 
            print(rand)
            if rand < p:
                nusers = next(numb_users)
                name = next(names_str)
                y = ('new', name, name)
                dic_names[nusers]= name[0]
            else:
                to_edit = prng.randint(0, nusers)
                print("to edit", to_edit, sep = " ")
                new_name = surname_change(old_name = dic_names[to_edit], males = male_names, prng=prng)
                y = ('change', (new_name, dic_names[to_edit]))
                dic_names[to_edit] = new_name

        yield (offset, y)

# %%
name = names(males = male_names, females = female_names, dist = 0.5, seed=123) # this is a name generator
sim= name_stream(mu=3, names_str = name, N=10, p=0.85, seed=143)

# %%
for i in range(200):
    print(next(sim))
# Out:
# <mtrand.RandomState object at 0x111a401e0>
# 0.052363598850944326
# (3, ('new', ('Herbjartur Kolfinnurson',), ('Herbjartur Kolfinnurson',)))
# 0.08718667752263232
# (5, ('new', ('Hákun Hervarðurson',), ('Hákun Hervarðurson',)))
# 0.4072417636703983
# (4, ('new', ('Sólmundur Benadiktson',), ('Sólmundur Benadiktson',)))
# 0.10770023493843905
# (2, ('new', ('Niklái Aleksson',), ('Niklái Aleksson',)))
# 0.9011988779516946
# (4, ('new', ('Brá Bergurdóttir',), ('Brá Bergurdóttir',)))
# 0.0381536661023224
# (3, ('new', ('Eyðbjartur Matsson',), ('Eyðbjartur Matsson',)))
# 0.5362020400339269
# (0, ('new', ('Berta Snævardóttir',), ('Berta Snævardóttir',)))
# 0.33219769850967984
# (3, ('new', ('Pál Birgarson',), ('Pál Birgarson',)))
# 0.8520866189293687
# (4, ('new', ('Ata Arnbjørndóttir',), ('Ata Arnbjørndóttir',)))
# 0.1596623967219699
# (3, ('new', ('Eyðsvein Liasson',), ('Eyðsvein Liasson',)))
# 0.3372166571092755
# (3, ('new', ('Hørður Bessison',), ('Hørður Bessison',)))
# 0.7377549616506409
# 0.3337963946289553
# (3, ('new', ('Valdi Hannisson',), ('Valdi Hannisson',)))
# 0.3399547406731225
# 0.24516335251761112
# (3, ('new', ('Ingivaldur Fríðmundurson',), ('Ingivaldur Fríðmundurson',)))
# 0.46809010087334957
# 0.0016705535792228554
# (3, ('new', ('Eskil Oddgeirson',), ('Eskil Oddgeirson',)))
# 0.42393801564202327
# 0.4362757934152184
# (2, ('new', ('Tóroddur Ásbrandurson',), ('Tóroddur Ásbrandurson',)))
# 0.5683196137805934
# 0.08761349975042287
# (2, ('new', ('Jóannes Tótison',), ('Jóannes Tótison',)))
# 0.8812808581628789
# to edit 13
# (0, ('change', ('Eskil Oddbjørnson', 'Eskil Oddgeirson')))
# 0.008783956523436887
# 0.6307704376118903
# (1, ('new', ('Hjalma Ábramdóttir',), ('Hjalma Ábramdóttir',)))
# 0.19923775690534407
# 0.5916227446021983
# (6, ('new', ('Hera Ápramdóttir',), ('Hera Ápramdóttir',)))
# 0.16726878825655045
# 0.059669262030168535
# (1, ('new', ('Mannbjørn Nikodemusson',), ('Mannbjørn Nikodemusson',)))
# 0.9689909052664663
# to edit 10
# (2, ('change', ('Hørður Ernstson', 'Hørður Bessison')))
# 0.14668958097428708
# 0.4004544810965167
# (1, ('new', ('Djóni Kjartanson',), ('Djóni Kjartanson',)))
# 0.9724372968770228
# to edit 15
# (0, ('change', ('Jóannes Eskilson', 'Jóannes Tótison')))
# 0.9766817174300038
# to edit 13
# (1, ('change', ('Eskil Robertson', 'Eskil Oddbjørnson')))
# 0.5639350346366817
# 0.24960259202167634
# (4, ('new', ('Vívil Borgarson',), ('Vívil Borgarson',)))
# 0.2715429307545252
# 0.7626876455011857
# (4, ('new', ('Jensia Benjamindóttir',), ('Jensia Benjamindóttir',)))
# 0.5073766636637834
# 0.2157081969488146
# (2, ('new', ('Edvard Vilbergurson',), ('Edvard Vilbergurson',)))
# 0.5992975843665959
# 0.5130172612225898
# (4, ('new', ('Eyðhild Hemingurdóttir',), ('Eyðhild Hemingurdóttir',)))
# 0.9867121921457211
# to edit 21
# (5, ('change', ('Jensia Bastiandóttir', 'Jensia Benjamindóttir')))
# 0.954447142496547
# to edit 5
# (2, ('change', ('Eyðbjartur Sunnleivurson', 'Eyðbjartur Matsson')))
# 0.18289426904231965
# 0.14541182743150527
# (7, ('new', ('Vilhjálmur Ottoson',), ('Vilhjálmur Ottoson',)))
# 0.8159387620282018
# 0.05041759010652891
# (6, ('new', ('Gripur Immanuelson',), ('Gripur Immanuelson',)))
# 0.28461482994857734
# 0.4104214278424263
# (3, ('new', ('Ronni Napoleonson',), ('Ronni Napoleonson',)))
# 0.6674764305495762
# 0.5818005170366584
# (3, ('new', ('Pálma Bergurdóttir',), ('Pálma Bergurdóttir',)))
# 0.9841564861592056
# to edit 3
# (2, ('change', ('Niklái Borgarson', 'Niklái Aleksson')))
# 0.805128611851796
# 0.7108079740306552
# (6, ('new', ('Kára Valbergurdóttir',), ('Kára Valbergurdóttir',)))
# 0.8241092326570796
# 0.7670587696087879
# (3, ('new', ('Jónleyg Tristandóttir',), ('Jónleyg Tristandóttir',)))
# 0.12117513632295385
# 0.36326723507841263
# (9, ('new', ('Signheðin Tobiasson',), ('Signheðin Tobiasson',)))
# 0.9366164148154632
# to edit 28
# (2, ('change', ('Kára Húnidóttir', 'Kára Valbergurdóttir')))
# 0.4503177309961064
# 0.9395517453246847
# (2, ('new', ('Maia Broddidóttir',), ('Maia Broddidóttir',)))
# 0.26099843655782673
# 0.2307886709456476
# (3, ('new', ('Immanuel Geirolvurson',), ('Immanuel Geirolvurson',)))
# 0.044117803111854315
# 0.5342514801600053
# (7, ('new', ('Døgg Svávardóttir',), ('Døgg Svávardóttir',)))
# 0.2675560846879462
# 0.08749299811811628
# (6, ('new', ('Mórits Edvardson',), ('Mórits Edvardson',)))
# 0.6677133276126745
# 0.42316160310121986
# (0, ('new', ('Hergrímur Herbjarturson',), ('Hergrímur Herbjarturson',)))
# 0.3501571987083081
# 0.5056309793898306
# (2, ('new', ('Sylvia Búidóttir',), ('Sylvia Búidóttir',)))
# 0.054122381232393324
# 0.8907922069447028
# (2, ('new', ('Vera Hjalmardóttir',), ('Vera Hjalmardóttir',)))
# 0.8739766010928417
# to edit 3
# (2, ('change', ('Niklái Eliasson', 'Niklái Borgarson')))
# 0.45474882729638477
# 0.4744021880040771
# (5, ('new', ('Flæmingur Fríðrikurson',), ('Flæmingur Fríðrikurson',)))
# 0.0130135309715248
# 0.7223859499944767
# (5, ('new', ('Brynja Hemmingurdóttir',), ('Brynja Hemmingurdóttir',)))
# 0.6753476062370662
# 0.6254003373227781
# (4, ('new', ('Elspa Magnidóttir',), ('Elspa Magnidóttir',)))
# 0.5240385703474991
# 0.15553719473422245
# (2, ('new', ('Sámal Helgison',), ('Sámal Helgison',)))
# 0.36202498232639546
# 0.8402972106781413
# (5, ('new', ('Klára Lávusdóttir',), ('Klára Lávusdóttir',)))
# 0.43286200055383095
# 0.45834982041186423
# (2, ('new', ('Gunnálvur Tráinson',), ('Gunnálvur Tráinson',)))
# 0.8278848377576689
# 0.3087223503377211
# (3, ('new', ('Laars Sørkvison',), ('Laars Sørkvison',)))
# 0.7496779405358596
# 0.5227378321523978
# (2, ('new', ('Marý Jónasdóttir',), ('Marý Jónasdóttir',)))
# 0.8018649752638543
# 0.28165173667753696
# (4, ('new', ('Ørvar Arngrímurson',), ('Ørvar Arngrímurson',)))
# 0.034647160392927034
# 0.6474049684195812
# (5, ('new', ('Hansina Sprotidóttir',), ('Hansina Sprotidóttir',)))
# 0.5914122350666787
# 0.4065289104401999
# (4, ('new', ('Hanus Arnoddurson',), ('Hanus Arnoddurson',)))
# 0.7688319457443592
# 0.46451206094547304
# (2, ('new', ('Ásbjørn Korneliusson',), ('Ásbjørn Korneliusson',)))
# 0.8124402509946912
# 0.9533721785062149
# (1, ('new', ('Sirið Brandurdóttir',), ('Sirið Brandurdóttir',)))
# 0.8852049285925631
# to edit 10
# (1, ('change', ('Hørður Vilbergurson', 'Hørður Ernstson')))
# 0.044776599257186134
# 0.8278502286575681
# (7, ('new', ('Ronja Jónsteindóttir',), ('Ronja Jónsteindóttir',)))
# 0.27570712797636543
# 0.3165581445584368
# (6, ('new', ('Heindrikur Jústinusson',), ('Heindrikur Jústinusson',)))
# 0.19803001193137437
# 0.5136297479512603
# (4, ('new', ('Gloria Absalondóttir',), ('Gloria Absalondóttir',)))
# 0.12467748366600562
# 0.9822632345253756
# (5, ('new', ('Fía Steintórdóttir',), ('Fía Steintórdóttir',)))
# 0.6600518513758418
# 0.15476443662337847
# (6, ('new', ('Geir Gabrielson',), ('Geir Gabrielson',)))
# 0.5355465344559062
# 0.6272278170080477
# (4, ('new', ('Aleksandra Baldurdóttir',), ('Aleksandra Baldurdóttir',)))
# 0.4877936919573449
# 0.9429191798932892
# (3, ('new', ('Erla Jónfinnurdóttir',), ('Erla Jónfinnurdóttir',)))
# 0.5108106164403124
# 0.700182836478906
# (1, ('new', ('Krista Brendandóttir',), ('Krista Brendandóttir',)))
# 0.8257842116777
# 0.9530775748121344
# (2, ('new', ('Jónvør Leivurdóttir',), ('Jónvør Leivurdóttir',)))
# 0.1650076109032329
# 0.5509890626563422
# (3, ('new', ('Salvør Yngvardóttir',), ('Salvør Yngvardóttir',)))
# 0.4124288057404464
# 0.20154948236851733
# (3, ('new', ('Elian Benjaminson',), ('Elian Benjaminson',)))
# 0.5374842744211261
# 0.7227976577519535
# (0, ('new', ('Malja Tormóðurdóttir',), ('Malja Tormóðurdóttir',)))
# 0.541965287624051
# 0.5231564478863852
# (4, ('new', ('Signhild Albindóttir',), ('Signhild Albindóttir',)))
# 0.6917251386971149
# 0.5817055374180974
# (2, ('new', ('Bjarnfríð Hendrikurdóttir',), ('Bjarnfríð Hendrikurdóttir',)))
# 0.8292541690997667
# 0.4096526964670424
# (8, ('new', ('Arnar Ávaldurson',), ('Arnar Ávaldurson',)))
# 0.21738120398080307
# 0.030670286269371627
# (3, ('new', ('Gustav Geirolvurson',), ('Gustav Geirolvurson',)))
# 0.6845910704803556
# 0.25665484646937897
# (1, ('new', ('Hørður Gudmarson',), ('Hørður Gudmarson',)))
# 0.24971896799591065
# 0.34909146784276
# (3, ('new', ('Jallgrímur Gulakurson',), ('Jallgrímur Gulakurson',)))
# 0.11142117246059424
# 0.2569709522272201
# (4, ('new', ('Ingimundur Sveinurson',), ('Ingimundur Sveinurson',)))
# 0.8834083137171443
# to edit 59
# (2, ('change', ('Jónvør Hallgrímurdóttir', 'Jónvør Leivurdóttir')))
# 0.334735390548634
# 0.002954144075295373
# (3, ('new', ('Úlvheðin Hildibjarturson',), ('Úlvheðin Hildibjarturson',)))
# 0.4219297188816291
# 0.8003157591450287
# (6, ('new', ('Maifríð Vilhelmdóttir',), ('Maifríð Vilhelmdóttir',)))
# 0.9338975766703851
# to edit 54
# (5, ('change', ('Fía Flosidóttir', 'Fía Steintórdóttir')))
# 0.4672236265705739
# 0.26854801494763747
# (1, ('new', ('Hagbarður Arnsveinson',), ('Hagbarður Arnsveinson',)))
# 0.7220254774898179
# 0.7756250309296249
# (7, ('new', ('Ulla Ørnolvurdóttir',), ('Ulla Ørnolvurdóttir',)))
# 0.1725173906602312
# 0.9860266956321891
# (3, ('new', ('Signuva Halgirdóttir',), ('Signuva Halgirdóttir',)))
# 0.47552288501518014
# 0.14591031150598022
# (2, ('new', ('Bresti Baldvinson',), ('Bresti Baldvinson',)))
# 0.5976510624848663
# 0.1775259116506257
# (2, ('new', ('Herbert Ímundurson',), ('Herbert Ímundurson',)))
# 0.8176035411041335
# 0.6334350269796983
# (2, ('new', ('Hjalma Gylvidóttir',), ('Hjalma Gylvidóttir',)))
# 0.2674736525938506
# 0.3651353954591192
# (2, ('new', ('Kaleb Ovison',), ('Kaleb Ovison',)))
# 0.07577980542459184
# 0.5421104674795767
# (3, ('new', ('Jennhild Juliandóttir',), ('Jennhild Juliandóttir',)))
# 0.9179177203004413
# to edit 0
# (3, ('change', ('Herbjartur Veturliðison', 'Herbjartur Kolfinnurson')))
# 0.21685011940763443
# 0.9939117101291661
# (3, ('new', ('Lotta Ingvaldurdóttir',), ('Lotta Ingvaldurdóttir',)))
# 0.7185915151689127
# 0.9287731091923055
# (5, ('new', ('Tóva Ørnolvurdóttir',), ('Tóva Ørnolvurdóttir',)))
# 0.06941788471839638
# 0.2311392936748402
# (3, ('new', ('Jørmundur Arnórson',), ('Jørmundur Arnórson',)))
# 0.2228375600973338
# 0.24740937499460403
# (3, ('new', ('Adrian Ásmóðurson',), ('Adrian Ásmóðurson',)))
# 0.9228632401040235
# to edit 21
# (4, ('change', ('Jensia Gripurdóttir', 'Jensia Bastiandóttir')))
# 0.30754327909966417
# 0.6519894369720243
# (6, ('new', ('Jónbjørg Esberndóttir',), ('Jónbjørg Esberndóttir',)))
# 0.3908876339075745
# 0.14732538282709184
# (6, ('new', ('Eyðolvur Ásarson',), ('Eyðolvur Ásarson',)))
# 0.09100231940624837
# 0.7995685126837923
# (1, ('new', ('Oda Elmardóttir',), ('Oda Elmardóttir',)))
# 0.07994723811969107
# 0.6758434263255023
# (1, ('new', ('Lina Ásleivurdóttir',), ('Lina Ásleivurdóttir',)))
# 0.6653279875112381
# 0.14963048768402365
# (1, ('new', ('Jøkil Róarson',), ('Jøkil Róarson',)))
# 0.7603015198871983
# 0.7934522307829109
# (2, ('new', ('Margret Oyolvurdóttir',), ('Margret Oyolvurdóttir',)))
# 0.7308281585597035
# 0.40418173726352336
# (2, ('new', ('Sørli Borgarson',), ('Sørli Borgarson',)))
# 0.1877457610330966
# 0.4891604537782013
# (3, ('new', ('Sunnleivur Ísmalson',), ('Sunnleivur Ísmalson',)))
# 0.41120958447311073
# 0.15400575864335153
# (4, ('new', ('Summarliði Frímannson',), ('Summarliði Frímannson',)))
# 0.011090430472640689
# 0.23146635472550436
# (7, ('new', ('Esbern Rósingurson',), ('Esbern Rósingurson',)))
# 0.5976716741854606
# 0.5428406697400346
# (2, ('new', ('Lona Jaspurdóttir',), ('Lona Jaspurdóttir',)))
# 0.3647857974706967
# 0.8371343390036157
# (3, ('new', ('Magga Meinharddóttir',), ('Magga Meinharddóttir',)))
# 0.8200121625113304
# 0.6190262245498506
# (5, ('new', ('Alma Korneliusdóttir',), ('Alma Korneliusdóttir',)))
# 0.8928224344419359
# to edit 0
# (6, ('change', ('Herbjartur Ragnarson', 'Herbjartur Veturliðison')))
# 0.04194769154056055
# 0.5233174420588009
# (1, ('new', ('Torfríð Baldvindóttir',), ('Torfríð Baldvindóttir',)))
# 0.37563822412955006
# 0.6327146870216482
# (0, ('new', ('Erika Eyðbjørndóttir',), ('Erika Eyðbjørndóttir',)))
# 0.882207278268177
# to edit 50
# (3, ('change', ('Sirið Loðindóttir', 'Sirið Brandurdóttir')))
# 0.9947973507948741
# to edit 58
# (5, ('change', ('Krista Egildóttir', 'Krista Brendandóttir')))
# 0.5928828702365752
# 0.6982985038591949
# (1, ('new', ('Olga Oddleivurdóttir',), ('Olga Oddleivurdóttir',)))
# 0.3046886991483789
# 0.92746698416777
# (2, ('new', ('Bylgja Helgidóttir',), ('Bylgja Helgidóttir',)))
# 0.05615614265323199
# 0.8851648873344187
# (2, ('new', ('Oddný Reimardóttir',), ('Oddný Reimardóttir',)))
# 0.5108612779686349
# 0.31789852289974396
# (2, ('new', ('Jósef Laarsson',), ('Jósef Laarsson',)))
# 0.03011389831912825
# 0.69730682011574
# (3, ('new', ('Marin Rúnolvurdóttir',), ('Marin Rúnolvurdóttir',)))
# 0.26838613849742043
# 0.7412698747570424
# (3, ('new', ('Paulina Áskildóttir',), ('Paulina Áskildóttir',)))
# 0.6582726734150225
# 0.47575782422392177
# (3, ('new', ('Ragnvaldur Sigbjarturson',), ('Ragnvaldur Sigbjarturson',)))
# 0.25875355784195697
# 0.21387709422619516
# (3, ('new', ('Bárður Høskuldurson',), ('Bárður Høskuldurson',)))
# 0.11610763623227538
# 0.738773972306009
# (1, ('new', ('Oddný Jóhannesdóttir',), ('Oddný Jóhannesdóttir',)))
# 0.7219467878476378
# 0.19137126509732283
# (4, ('new', ('Játmundur Oymundurson',), ('Játmundur Oymundurson',)))
# 0.6173638440385785
# 0.28046097013853477
# (3, ('new', ('Høgnar Eindrison',), ('Høgnar Eindrison',)))
# 0.8713162283460866
# to edit 68
# (5, ('change', ('Jallgrímur Onundurson', 'Jallgrímur Gulakurson')))
# 0.6713555567137525
# 0.3504385046430585
# (2, ('new', ('Tórarin Gíslison',), ('Tórarin Gíslison',)))
# 0.35504567296147915
# 0.7829764889549333
# (1, ('new', ('Røskva Jatmundurdóttir',), ('Røskva Jatmundurdóttir',)))
# 0.0910071502335944
# 0.9304629441678834
# (3, ('new', ('Gloria Knúturdóttir',), ('Gloria Knúturdóttir',)))
# 0.4992485938329151
# 0.9465319221985645
# (2, ('new', ('Svanna Oddmundurdóttir',), ('Svanna Oddmundurdóttir',)))
# 0.4986705819192886
# 0.2107701206008229
# (4, ('new', ('Kálvur Hansson',), ('Kálvur Hansson',)))
# 0.060052922116654806
# 0.9023383507991123
# (2, ('new', ('Heiðveig Jákupdóttir',), ('Heiðveig Jákupdóttir',)))
# 0.5704833930338336
# 0.30221670957276003
# (2, ('new', ('Oddur Vigfússon',), ('Oddur Vigfússon',)))
# 0.9186098390511229
# to edit 91
# (2, ('change', ('Sunnleivur Gylvison', 'Sunnleivur Ísmalson')))
# 0.5696861971706386
# 0.4187107864787206
# (2, ('new', ('Betuel Hallbjørnson',), ('Betuel Hallbjørnson',)))
# 0.08922738791988694
# 0.5599180076856662
# (2, ('new', ('Palma Gunnsteindóttir',), ('Palma Gunnsteindóttir',)))
# 0.6169064954127644
# 0.8595907848995924
# (3, ('new', ('Emilý Rafaeldóttir',), ('Emilý Rafaeldóttir',)))
# 0.30509024249539374
# 0.07244468432529938
# (4, ('new', ('Ásfinnur Rógvison',), ('Ásfinnur Rógvison',)))
# 0.9628667849770276
# to edit 44
# (1, ('change', ('Laars Símeonson', 'Laars Sørkvison')))
# 0.5662293010702893
# 0.540013890090415
# (3, ('new', ('Jónhild Oysteindóttir',), ('Jónhild Oysteindóttir',)))
# 0.27306107376677724
# 0.12834921095635576
# (2, ('new', ('Fríði Esekielson',), ('Fríði Esekielson',)))
# 0.3755143482347142
# 0.3615827754594382
# (0, ('new', ('Hákun Leoson',), ('Hákun Leoson',)))
# 0.2982773704110393
# 0.1882611074639815
# (7, ('new', ('Sólbjørn Aggusteinusson',), ('Sólbjørn Aggusteinusson',)))
# 0.9285508174277208
# to edit 88
# (1, ('change', ('Jøkil Fálgeirson', 'Jøkil Róarson')))
# 0.17656621603050937
# 0.7011579340148163
# (3, ('new', ('Unnur Syftundóttir',), ('Unnur Syftundóttir',)))
# 0.45977821031153554
# 0.6555687157272841
# (2, ('new', ('Tanja Tókidóttir',), ('Tanja Tókidóttir',)))
# 0.27345274584379375
# 0.47252754829253274
# (2, ('new', ('Gripur Sámalson',), ('Gripur Sámalson',)))
# 0.2563155305364414
# 0.632674941772076
# (6, ('new', ('Havdis Gudfinnurdóttir',), ('Havdis Gudfinnurdóttir',)))
# 0.10531978902810024
# 0.5875673611999923
# (2, ('new', ('Snjófríð Vigfúsdóttir',), ('Snjófríð Vigfúsdóttir',)))
# 0.06376064098444478
# 0.5408950527928408
# (6, ('new', ('Elspa Hórðurdóttir',), ('Elspa Hórðurdóttir',)))
# 0.46951342933847107
# 0.6701283931134239
# (1, ('new', ('Hallvør Eliasdóttir',), ('Hallvør Eliasdóttir',)))
# 0.8971315119050075
# to edit 33
# (2, ('change', ('Døgg Beinardóttir', 'Døgg Svávardóttir')))
# 0.5711135933059448
# 0.18570454130753866
# (1, ('new', ('Bótolvur Aggusteinusson',), ('Bótolvur Aggusteinusson',)))
# 0.2815935622263681
# 0.1743755305528757
# (3, ('new', ('Gísli Stígurson',), ('Gísli Stígurson',)))
# 0.06094393396331732
# 0.41581046980436986
# (1, ('new', ('Mikal Heinison',), ('Mikal Heinison',)))
# 0.1978726223323154
# 0.9625200218429996
# (3, ('new', ('Henrikka Oskardóttir',), ('Henrikka Oskardóttir',)))
# 0.29164671178885104
# 0.40483416509507053
# (1, ('new', ('Jóel Kristinson',), ('Jóel Kristinson',)))
# 0.5251427373170305
# 0.7657981352017609
# (3, ('new', ('Finngerð Vilmardóttir',), ('Finngerð Vilmardóttir',)))
# 0.5566675538415181
# 0.5295306648286207
# (2, ('new', ('Felisia Rómundurdóttir',), ('Felisia Rómundurdóttir',)))
# 0.34291234971142115
# 0.06314564833458525
# (2, ('new', ('Bragi Ingmarson',), ('Bragi Ingmarson',)))
# 0.7225503577863615
# 0.41393492284521316
# (6, ('new', ('Jústinus Dávidson',), ('Jústinus Dávidson',)))
# 0.09383206564476698
# 0.015362142055277084
# (3, ('new', ('Klæmint Hallbergurson',), ('Klæmint Hallbergurson',)))
# 0.7755214108580635
# 0.11008442210729852
# (2, ('new', ('Sonni Eyðbjørnson',), ('Sonni Eyðbjørnson',)))
# 0.8025867948687392
# 0.778176914251132
# (2, ('new', ('Rebekka Húnbogidóttir',), ('Rebekka Húnbogidóttir',)))
# 0.7645474666708688
# 0.4037307057977134
# (2, ('new', ('Arinbjørn Tórolvurson',), ('Arinbjørn Tórolvurson',)))
# 0.3569828105082422
# 0.3393332363904963
# (2, ('new', ('Hannis Nóison',), ('Hannis Nóison',)))
# 0.4383753268305133
# 0.9795962201345553
# (2, ('new', ('Jóanna Hámundurdóttir',), ('Jóanna Hámundurdóttir',)))
# 0.008386041693404844
# 0.7021586932562662
# (2, ('new', ('Paula Bernardóttir',), ('Paula Bernardóttir',)))
# 0.8597817857443438
# to edit 133
# (7, ('change', ('Gísli Hjálmarson', 'Gísli Stígurson')))
# 0.08964975635123562
# 0.9753959979425557
# (5, ('new', ('Gabriella Vitusdóttir',), ('Gabriella Vitusdóttir',)))
# 0.19385116421720683
# 0.2786881934646811
# (5, ('new', ('Aksel Summarliðison',), ('Aksel Summarliðison',)))
# 0.649044651873816
# 0.02078068125516741
# (4, ('new', ('Tummas Lavarsson',), ('Tummas Lavarsson',)))
# 0.07494088998741533
# 0.9134326177479648
# (3, ('new', ('Randfríð Óttardóttir',), ('Randfríð Óttardóttir',)))
# 0.45979137102286327
# 0.6093128360239264
# (4, ('new', ('Fríðrun Steinmundurdóttir',), ('Fríðrun Steinmundurdóttir',)))
# 0.18998396999607148
# 0.22223918068876447
# (2, ('new', ('Bjørgfinnur Brynleivurson',), ('Bjørgfinnur Brynleivurson',)))
# 0.3106849591297951
# 0.9789991065483834
# (4, ('new', ('Lisabet Brialdurdóttir',), ('Lisabet Brialdurdóttir',)))
# 0.9978647448755282
# to edit 137
# (1, ('change', ('Finngerð Antinesdóttir', 'Finngerð Vilmardóttir')))
# 0.794332523786324
# 0.11752610405109198
# (2, ('new', ('Jørundur Pállson',), ('Jørundur Pállson',)))
# 0.5536783634487227
# 0.8204715481821426
# (7, ('new', ('Torborg Nikodemusdóttir',), ('Torborg Nikodemusdóttir',)))
# 0.8373148502778383
# 0.20503200387284137
# (6, ('new', ('Eyði Steingrímurson',), ('Eyði Steingrímurson',)))
# 0.6759612107720152
# 0.9804465032746214
# (5, ('new', ('Matthild Ørvardóttir',), ('Matthild Ørvardóttir',)))
# 0.8256967292004872
# 0.264324341849837
# (3, ('new', ('Lias Brúsison',), ('Lias Brúsison',)))
# 0.24142113402322152
# 0.9845004951060085
# (2, ('new', ('Jófríð Ingolvurdóttir',), ('Jófríð Ingolvurdóttir',)))
# 0.16163914662822487
# 0.548868730299502
# (3, ('new', ('Bjalla Villiamdóttir',), ('Bjalla Villiamdóttir',)))
# 0.026999353824978534
# 0.8067483621911211
# (4, ('new', ('Ronja Jónatandóttir',), ('Ronja Jónatandóttir',)))
# 0.3478666368680218
# 0.3498300948751334
# (5, ('new', ('Hemmingur Vígúlvurson',), ('Hemmingur Vígúlvurson',)))
# 0.016440419013145635
# 0.16214213122758903
# (6, ('new', ('Mattas Ingimundurson',), ('Mattas Ingimundurson',)))
# 0.20144718501376002
# 0.7147555937016391
# (3, ('new', ('Maisól Svenningurdóttir',), ('Maisól Svenningurdóttir',)))
# 0.3054486212344695
# 0.675223908638972
# (4, ('new', ('Elin Janusdóttir',), ('Elin Janusdóttir',)))
# 0.9112221926359143
# to edit 105
# (5, ('change', ('Ragnvaldur Havsteinson', 'Ragnvaldur Sigbjarturson')))
# 0.5179135191515498
# 0.7898946072217509
# (2, ('new', ('Marnhild Tobiasdóttir',), ('Marnhild Tobiasdóttir',)))
# 0.16920587759124794
# 0.8084824029704005
# (1, ('new', ('Herta Árnidóttir',), ('Herta Árnidóttir',)))
# 0.36636410026521005
# 0.6469666555540791
# (4, ('new', ('Belinda Kaidóttir',), ('Belinda Kaidóttir',)))
# 0.8827744987585157
# to edit 12
# (1, ('change', ('Ingivaldur Hermundurson', 'Ingivaldur Fríðmundurson')))
# 0.7515985347582257
# 0.8439831737147954
# (4, ('new', ('Poulina Havsteindóttir',), ('Poulina Havsteindóttir',)))
# 0.6597473451497272
# 0.8069630283207204
# (1, ('new', ('Marianna Ápramdóttir',), ('Marianna Ápramdóttir',)))
# 0.9334844100803364
# to edit 77
# (2, ('change', ('Hjalma Eldbjørndóttir', 'Hjalma Gylvidóttir')))
# 0.8344916757537035
# 0.6401172842351421
# (3, ('new', ('Hildibjørt Vestardóttir',), ('Hildibjørt Vestardóttir',)))
